# %%
import logging
from mirt import MIRT
from adcd_run import ADCD_Runner

logging.basicConfig(level=logging.INFO)

# %%
hyperparams = {
    'dim': 16, 
    'lr': 0.002,  
    'batch_size': 256,
    'epochs': 50,
    'seed': 123
}

# %% [markdown]
# # Real

# %% [markdown]
# ### ASSIST

# %%
runner = ADCD_Runner(
    model_class=MIRT,
    input_dir='../../Data/data/A123',
    split_type='real',
    train_fraction=1.0,
    **hyperparams
)
runner.run()
# Out:
# 2026-02-06 20:08:23,595 - INFO - Using device: cuda
# 2026-02-06 20:08:23,607 - INFO - Loading metadata and p2k mapping...
# 2026-02-06 20:08:23,621 - INFO - 2493 users, 17676 problems, 123 skills.
# 2026-02-06 20:08:23,646 - INFO - Pre-building global problem Q-matrix...
# 2026-02-06 20:08:24,416 - INFO -
# ==================== Starting Real-Scenario (Time-Series) Split ====================
# 2026-02-06 20:08:25,108 - INFO - real_split: Train=159500, Val=52549, Test=55374
# 2026-02-06 20:08:29,188 - INFO - Training MIRT (dim=16)... (lr=0.002)
# Epoch 1/50: 100%|██████████| 624/624 [00:03<00:00, 200.86it/s]
# 2026-02-06 20:08:32,311 - INFO - [Epoch 1] Average Loss: 0.600986
# Evaluating: 100%|██████████| 206/206 [00:00<00:00, 426.83it/s]
# 2026-02-06 20:08:32,839 - INFO - [Epoch 1] Validation AUC: 0.700223, ACC: 0.696930
# 2026-02-06 20:08:32,852 - INFO - save parameters to paras_EADCD\model_real_real_split.snapshot
# 2026-02-06 20:08:32,852 - INFO - Valid improvement (0.700223 > 0.001). Model saved.
# Epoch 2/50: 100%|██████████| 624/624 [00:02<00:00, 250.63it/s]
# 2026-02-06 20:08:35,343 - INFO - [Epoch 2] Average Loss: 0.554873
# Evaluating: 100%|██████████| 206/206 [00:00<00:00, 417.67it/s]
# 2026-02-06 20:08:35,877 - INFO - [Epoch 2] Validation AUC: 0.713309, ACC: 0.701783
# 2026-02-06 20:08:35,880 - INFO - save parameters to paras_EADCD\model_real_real_split.snapshot
# 2026-02-06 20:08:35,881 - INFO - Valid improvement (0.013086 > 0.001). Model saved.
# Epoch 3/50: 100%|██████████| 624/624 [00:02<00:00, 235.80it/s]
# 2026-02-06 20:08:38,529 - INFO - [Epoch 3] Average Loss: 0.535509
# Evaluating: 100%|██████████| 206/206 [00:00<00:00, 410.44it/s]
# 2026-02-06 20:08:39,072 - INFO - [Epoch 3] Validation AUC: 0.722980, ACC: 0.706731
# 2026-02-06 20:08:39,086 - INFO - save parameters to paras_EADCD\model_real_real_split.snapshot
# 2026-02-06 20:08:39,087 - INFO - Valid improvement (0.009671 > 0.001). Model saved.
# Epoch 4/50: 100%|██████████| 624/624 [00:02<00:00, 212.25it/s]
# 2026-02-06 20:08:42,031 - INFO - [Epoch 4] Average Loss: 0.520140
# Evaluating: 100%|██████████| 206/206 [00:00<00:00, 420.66it/s]
# 2026-02-06 20:08:42,561 - INFO - [Epoch 4] Validation AUC: 0.730840, ACC: 0.709566
# 2026-02-06 20:08:42,564 - INFO - save parameters to paras_EADCD\model_real_real_split.snapshot
# 2026-02-06 20:08:42,574 - INFO - Valid improvement (0.007860 > 0.001). Model saved.
# Epoch 5/50: 100%|██████████| 624/624 [00:02<00:00, 229.28it/s]
# 2026-02-06 20:08:45,296 - INFO - [Epoch 5] Average Loss: 0.506140
# Evaluating: 100%|██████████| 206/206 [00:00<00:00, 420.35it/s]
# 2026-02-06 20:08:45,826 - INFO - [Epoch 5] Validation AUC: 0.737774, ACC: 0.715523
# 2026-02-06 20:08:45,829 - INFO - save parameters to paras_EADCD\model_real_real_split.snapshot
# 2026-02-06 20:08:45,830 - INFO - Valid improvement (0.006933 > 0.001). Model saved.
# Epoch 6/50: 100%|██████████| 624/624 [00:02<00:00, 230.05it/s]
# 2026-02-06 20:08:48,544 - INFO - [Epoch 6] Average Loss: 0.493450
# Evaluating: 100%|██████████| 206/206 [00:00<00:00, 433.88it/s]
# 2026-02-06 20:08:49,068 - INFO - [Epoch 6] Validation AUC: 0.739909, ACC: 0.718092
# 2026-02-06 20:08:49,071 - INFO - save parameters to paras_EADCD\model_real_real_split.snapshot
# 2026-02-06 20:08:49,071 - INFO - Valid improvement (0.002135 > 0.001). Model saved.
# Epoch 7/50: 100%|██████████| 624/624 [00:02<00:00, 228.22it/s]
# 2026-02-06 20:08:51,807 - INFO - [Epoch 7] Average Loss: 0.479918
# Evaluating: 100%|██████████| 206/206 [00:00<00:00, 431.19it/s]
# 2026-02-06 20:08:52,344 - INFO - [Epoch 7] Validation AUC: 0.745486, ACC: 0.721365
# 2026-02-06 20:08:52,348 - INFO - save parameters to paras_EADCD\model_real_real_split.snapshot
# 2026-02-06 20:08:52,349 - INFO - Valid improvement (0.005577 > 0.001). Model saved.
# Epoch 8/50: 100%|██████████| 624/624 [00:02<00:00, 234.87it/s]
# 2026-02-06 20:08:55,008 - INFO - [Epoch 8] Average Loss: 0.465194
# Evaluating: 100%|██████████| 206/206 [00:00<00:00, 423.02it/s]
# 2026-02-06 20:08:55,538 - INFO - [Epoch 8] Validation AUC: 0.750508, ACC: 0.725475
# 2026-02-06 20:08:55,543 - INFO - save parameters to paras_EADCD\model_real_real_split.snapshot
# 2026-02-06 20:08:55,543 - INFO - Valid improvement (0.005022 > 0.001). Model saved.
# Epoch 9/50: 100%|██████████| 624/624 [00:02<00:00, 239.32it/s]
# 2026-02-06 20:08:58,153 - INFO - [Epoch 9] Average Loss: 0.448164
# Evaluating: 100%|██████████| 206/206 [00:00<00:00, 403.93it/s]
# 2026-02-06 20:08:58,714 - INFO - [Epoch 9] Validation AUC: 0.755139, ACC: 0.728197
# 2026-02-06 20:08:58,717 - INFO - save parameters to paras_EADCD\model_real_real_split.snapshot
# 2026-02-06 20:08:58,717 - INFO - Valid improvement (0.004631 > 0.001). Model saved.
# Epoch 10/50: 100%|██████████| 624/624 [00:02<00:00, 218.38it/s]
# 2026-02-06 20:09:01,576 - INFO - [Epoch 10] Average Loss: 0.429433
# Evaluating: 100%|██████████| 206/206 [00:00<00:00, 432.28it/s]
# 2026-02-06 20:09:02,106 - INFO - [Epoch 10] Validation AUC: 0.759895, ACC: 0.730328
# 2026-02-06 20:09:02,109 - INFO - save parameters to paras_EADCD\model_real_real_split.snapshot
# 2026-02-06 20:09:02,109 - INFO - Valid improvement (0.004756 > 0.001). Model saved.
# Epoch 11/50: 100%|██████████| 624/624 [00:02<00:00, 243.33it/s]
# 2026-02-06 20:09:04,676 - INFO - [Epoch 11] Average Loss: 0.409373
# Evaluating: 100%|██████████| 206/206 [00:00<00:00, 418.39it/s]
# 2026-02-06 20:09:05,209 - INFO - [Epoch 11] Validation AUC: 0.761965, ACC: 0.733696
# 2026-02-06 20:09:05,211 - INFO - save parameters to paras_EADCD\model_real_real_split.snapshot
# 2026-02-06 20:09:05,211 - INFO - Valid improvement (0.002070 > 0.001). Model saved.
# Epoch 12/50: 100%|██████████| 624/624 [00:02<00:00, 242.33it/s]
# 2026-02-06 20:09:07,789 - INFO - [Epoch 12] Average Loss: 0.388050
# Evaluating: 100%|██████████| 206/206 [00:00<00:00, 428.33it/s]
# 2026-02-06 20:09:08,314 - INFO - [Epoch 12] Validation AUC: 0.765391, ACC: 0.734077
# 2026-02-06 20:09:08,318 - INFO - save parameters to paras_EADCD\model_real_real_split.snapshot
# 2026-02-06 20:09:08,318 - INFO - Valid improvement (0.003426 > 0.001). Model saved.
# Epoch 13/50: 100%|██████████| 624/624 [00:02<00:00, 237.35it/s]
# 2026-02-06 20:09:10,949 - INFO - [Epoch 13] Average Loss: 0.365658
# Evaluating: 100%|██████████| 206/206 [00:00<00:00, 415.83it/s]
# 2026-02-06 20:09:11,484 - INFO - [Epoch 13] Validation AUC: 0.767650, ACC: 0.733944
# 2026-02-06 20:09:11,486 - INFO - save parameters to paras_EADCD\model_real_real_split.snapshot
# 2026-02-06 20:09:11,486 - INFO - Valid improvement (0.002258 > 0.001). Model saved.
# Epoch 14/50: 100%|██████████| 624/624 [00:02<00:00, 231.06it/s]
# 2026-02-06 20:09:14,187 - INFO - [Epoch 14] Average Loss: 0.343638
# Evaluating: 100%|██████████| 206/206 [00:00<00:00, 400.88it/s]
# 2026-02-06 20:09:14,746 - INFO - [Epoch 14] Validation AUC: 0.768938, ACC: 0.735161
# 2026-02-06 20:09:14,746 - INFO - save parameters to paras_EADCD\model_real_real_split.snapshot
# 2026-02-06 20:09:14,751 - INFO - Valid improvement (0.001288 > 0.001). Model saved.
# Epoch 15/50: 100%|██████████| 624/624 [00:02<00:00, 223.78it/s]
# 2026-02-06 20:09:17,542 - INFO - [Epoch 15] Average Loss: 0.321459
# Evaluating: 100%|██████████| 206/206 [00:00<00:00, 404.71it/s]
# 2026-02-06 20:09:18,092 - INFO - [Epoch 15] Validation AUC: 0.770199, ACC: 0.735980
# 2026-02-06 20:09:18,096 - INFO - save parameters to paras_EADCD\model_real_real_split.snapshot
# 2026-02-06 20:09:18,096 - INFO - Valid improvement (0.001260 > 0.001). Model saved.
# Epoch 16/50: 100%|██████████| 624/624 [00:02<00:00, 222.82it/s]
# 2026-02-06 20:09:20,899 - INFO - [Epoch 16] Average Loss: 0.299991
# Evaluating: 100%|██████████| 206/206 [00:00<00:00, 419.41it/s]
# 2026-02-06 20:09:21,431 - INFO - [Epoch 16] Validation AUC: 0.771022, ACC: 0.736646
# 2026-02-06 20:09:21,432 - INFO - Early stopping triggered at epoch 16.
# 2026-02-06 20:09:21,432 - INFO - --- real_split Best epoch: 15 ---
# 2026-02-06 20:09:21,433 - INFO - Loading best model from real_split for final test evaluation...
# 2026-02-06 20:09:21,478 - INFO - load parameters from paras_EADCD\model_real_real_split.snapshot
# Evaluating: 100%|██████████| 217/217 [00:00<00:00, 409.76it/s]
# 2026-02-06 20:09:22,055 - INFO - real_split Test Performance --- AUC: 0.752385, ACC: 0.714090, RMSE: 0.438301, F1: 0.789053
# ==================== Real-Scenario (Time-Series) Split Final Results ====================
# Parameters: train_fraction=1.0, epochs=50, seed=123
# AUC:  0.752385
# ACC:  0.714090
# RMSE: 0.438301
# F1:   0.789053

# %% [markdown]
# ### junyi

# %%
runner = ADCD_Runner(
    model_class=MIRT,
    input_dir='../../Data/data/J123',
    split_type='real',
    train_fraction=1.0,
    **hyperparams
)
runner.run()
# Out:
# 2026-02-06 20:09:22,076 - INFO - Using device: cuda
# 2026-02-06 20:09:22,079 - INFO - Loading metadata and p2k mapping...
# 2026-02-06 20:09:22,082 - INFO - 10000 users, 675 problems, 510 skills.
# 2026-02-06 20:09:22,085 - INFO - Pre-building global problem Q-matrix...
# 2026-02-06 20:09:22,117 - INFO -
# ==================== Starting Real-Scenario (Time-Series) Split ====================
# 2026-02-06 20:09:25,469 - INFO - real_split: Train=241905, Val=78170, Test=89543
# 2026-02-06 20:09:48,657 - INFO - Training MIRT (dim=16)... (lr=0.002)
# Epoch 1/50: 100%|██████████| 945/945 [00:04<00:00, 191.60it/s]
# 2026-02-06 20:09:53,594 - INFO - [Epoch 1] Average Loss: 0.546615
# Evaluating: 100%|██████████| 306/306 [00:00<00:00, 388.14it/s]
# 2026-02-06 20:09:54,446 - INFO - [Epoch 1] Validation AUC: 0.763199, ACC: 0.712729
# 2026-02-06 20:09:54,449 - INFO - save parameters to paras_EADCD\model_real_real_split.snapshot
# 2026-02-06 20:09:54,450 - INFO - Valid improvement (0.763199 > 0.001). Model saved.
# Epoch 2/50: 100%|██████████| 945/945 [00:04<00:00, 201.74it/s]
# 2026-02-06 20:09:59,136 - INFO - [Epoch 2] Average Loss: 0.471866
# Evaluating: 100%|██████████| 306/306 [00:00<00:00, 332.76it/s]
# 2026-02-06 20:10:00,141 - INFO - [Epoch 2] Validation AUC: 0.778129, ACC: 0.731764
# 2026-02-06 20:10:00,144 - INFO - save parameters to paras_EADCD\model_real_real_split.snapshot
# 2026-02-06 20:10:00,145 - INFO - Valid improvement (0.014930 > 0.001). Model saved.
# Epoch 3/50: 100%|██████████| 945/945 [00:04<00:00, 197.98it/s]
# 2026-02-06 20:10:04,920 - INFO - [Epoch 3] Average Loss: 0.456532
# Evaluating: 100%|██████████| 306/306 [00:00<00:00, 395.81it/s]
# 2026-02-06 20:10:05,757 - INFO - [Epoch 3] Validation AUC: 0.784273, ACC: 0.739286
# 2026-02-06 20:10:05,760 - INFO - save parameters to paras_EADCD\model_real_real_split.snapshot
# 2026-02-06 20:10:05,761 - INFO - Valid improvement (0.006144 > 0.001). Model saved.
# Epoch 4/50: 100%|██████████| 945/945 [00:04<00:00, 208.46it/s]
# 2026-02-06 20:10:10,296 - INFO - [Epoch 4] Average Loss: 0.448390
# Evaluating: 100%|██████████| 306/306 [00:00<00:00, 405.44it/s]
# 2026-02-06 20:10:11,119 - INFO - [Epoch 4] Validation AUC: 0.787177, ACC: 0.743277
# 2026-02-06 20:10:11,119 - INFO - save parameters to paras_EADCD\model_real_real_split.snapshot
# 2026-02-06 20:10:11,119 - INFO - Valid improvement (0.002903 > 0.001). Model saved.
# Epoch 5/50: 100%|██████████| 945/945 [00:04<00:00, 207.15it/s]
# 2026-02-06 20:10:15,681 - INFO - [Epoch 5] Average Loss: 0.442450
# Evaluating: 100%|██████████| 306/306 [00:00<00:00, 362.85it/s]
# 2026-02-06 20:10:16,586 - INFO - [Epoch 5] Validation AUC: 0.789305, ACC: 0.745478
# 2026-02-06 20:10:16,589 - INFO - save parameters to paras_EADCD\model_real_real_split.snapshot
# 2026-02-06 20:10:16,590 - INFO - Valid improvement (0.002129 > 0.001). Model saved.
# Epoch 6/50: 100%|██████████| 945/945 [00:04<00:00, 218.05it/s]
# 2026-02-06 20:10:20,926 - INFO - [Epoch 6] Average Loss: 0.437426
# Evaluating: 100%|██████████| 306/306 [00:00<00:00, 359.72it/s]
# 2026-02-06 20:10:21,838 - INFO - [Epoch 6] Validation AUC: 0.790807, ACC: 0.746463
# 2026-02-06 20:10:21,841 - INFO - save parameters to paras_EADCD\model_real_real_split.snapshot
# 2026-02-06 20:10:21,843 - INFO - Valid improvement (0.001502 > 0.001). Model saved.
# Epoch 7/50: 100%|██████████| 945/945 [00:04<00:00, 202.92it/s]
# 2026-02-06 20:10:26,502 - INFO - [Epoch 7] Average Loss: 0.431373
# Evaluating: 100%|██████████| 306/306 [00:00<00:00, 342.78it/s]
# 2026-02-06 20:10:27,463 - INFO - [Epoch 7] Validation AUC: 0.792005, ACC: 0.748228
# 2026-02-06 20:10:27,466 - INFO - save parameters to paras_EADCD\model_real_real_split.snapshot
# 2026-02-06 20:10:27,466 - INFO - Valid improvement (0.001199 > 0.001). Model saved.
# Epoch 8/50: 100%|██████████| 945/945 [00:04<00:00, 205.97it/s]
# 2026-02-06 20:10:32,057 - INFO - [Epoch 8] Average Loss: 0.422222
# Evaluating: 100%|██████████| 306/306 [00:00<00:00, 356.31it/s]
# 2026-02-06 20:10:32,979 - INFO - [Epoch 8] Validation AUC: 0.791997, ACC: 0.748395
# 2026-02-06 20:10:32,980 - INFO - Early stopping triggered at epoch 8.
# 2026-02-06 20:10:32,982 - INFO - --- real_split Best epoch: 7 ---
# 2026-02-06 20:10:32,982 - INFO - Loading best model from real_split for final test evaluation...
# 2026-02-06 20:10:32,988 - INFO - load parameters from paras_EADCD\model_real_real_split.snapshot
# Evaluating: 100%|██████████| 350/350 [00:00<00:00, 395.52it/s]
# 2026-02-06 20:10:33,945 - INFO - real_split Test Performance --- AUC: 0.775076, ACC: 0.725986, RMSE: 0.429571, F1: 0.790237
# ==================== Real-Scenario (Time-Series) Split Final Results ====================
# Parameters: train_fraction=1.0, epochs=50, seed=123
# AUC:  0.775076
# ACC:  0.725986
# RMSE: 0.429571
# F1:   0.790237

# %% [markdown]
# ### NIPS

# %%
runner = ADCD_Runner(
    model_class=MIRT,
    input_dir='../../Data/data/N123',
    split_type='real',
    train_fraction=1.0,
    **hyperparams
)
runner.run()
# Out:
# 2026-02-06 20:10:34,082 - INFO - Using device: cuda
# 2026-02-06 20:10:34,083 - INFO - Loading metadata and p2k mapping...
# 2026-02-06 20:10:34,092 - INFO - 10000 users, 27599 problems, 388 skills.
# 2026-02-06 20:10:34,101 - INFO - Pre-building global problem Q-matrix...
# 2026-02-06 20:10:35,513 - INFO -
# ==================== Starting Real-Scenario (Time-Series) Split ====================
# 2026-02-06 20:10:47,119 - INFO - real_split: Train=999746, Val=331031, Test=341263
# 2026-02-06 20:12:03,795 - INFO - Training MIRT (dim=16)... (lr=0.002)
# Epoch 1/50: 100%|██████████| 3906/3906 [00:18<00:00, 216.98it/s]
# 2026-02-06 20:12:21,812 - INFO - [Epoch 1] Average Loss: 0.577573
# Evaluating: 100%|██████████| 1294/1294 [00:03<00:00, 358.38it/s]
# 2026-02-06 20:12:25,702 - INFO - [Epoch 1] Validation AUC: 0.755312, ACC: 0.706901
# 2026-02-06 20:12:25,712 - INFO - save parameters to paras_EADCD\model_real_real_split.snapshot
# 2026-02-06 20:12:25,712 - INFO - Valid improvement (0.755312 > 0.001). Model saved.
# Epoch 2/50: 100%|██████████| 3906/3906 [00:19<00:00, 202.72it/s]
# 2026-02-06 20:12:44,984 - INFO - [Epoch 2] Average Loss: 0.541499
# Evaluating: 100%|██████████| 1294/1294 [00:03<00:00, 368.57it/s]
# 2026-02-06 20:12:48,767 - INFO - [Epoch 2] Validation AUC: 0.768503, ACC: 0.716371
# 2026-02-06 20:12:48,776 - INFO - save parameters to paras_EADCD\model_real_real_split.snapshot
# 2026-02-06 20:12:48,777 - INFO - Valid improvement (0.013191 > 0.001). Model saved.
# Epoch 3/50: 100%|██████████| 3906/3906 [00:18<00:00, 215.20it/s]
# 2026-02-06 20:13:06,931 - INFO - [Epoch 3] Average Loss: 0.528753
# Evaluating: 100%|██████████| 1294/1294 [00:03<00:00, 377.82it/s]
# 2026-02-06 20:13:10,628 - INFO - [Epoch 3] Validation AUC: 0.772925, ACC: 0.720842
# 2026-02-06 20:13:10,633 - INFO - save parameters to paras_EADCD\model_real_real_split.snapshot
# 2026-02-06 20:13:10,634 - INFO - Valid improvement (0.004422 > 0.001). Model saved.
# Epoch 4/50: 100%|██████████| 3906/3906 [00:17<00:00, 224.69it/s]
# 2026-02-06 20:13:28,020 - INFO - [Epoch 4] Average Loss: 0.520802
# Evaluating: 100%|██████████| 1294/1294 [00:03<00:00, 368.12it/s]
# 2026-02-06 20:13:31,814 - INFO - [Epoch 4] Validation AUC: 0.774958, ACC: 0.722008
# 2026-02-06 20:13:31,818 - INFO - save parameters to paras_EADCD\model_real_real_split.snapshot
# 2026-02-06 20:13:31,821 - INFO - Valid improvement (0.002033 > 0.001). Model saved.
# Epoch 5/50: 100%|██████████| 3906/3906 [00:17<00:00, 226.65it/s]
# 2026-02-06 20:13:49,056 - INFO - [Epoch 5] Average Loss: 0.513104
# Evaluating: 100%|██████████| 1294/1294 [00:03<00:00, 371.08it/s]
# 2026-02-06 20:13:52,819 - INFO - [Epoch 5] Validation AUC: 0.776133, ACC: 0.722975
# 2026-02-06 20:13:52,825 - INFO - save parameters to paras_EADCD\model_real_real_split.snapshot
# 2026-02-06 20:13:52,826 - INFO - Valid improvement (0.001175 > 0.001). Model saved.
# Epoch 6/50: 100%|██████████| 3906/3906 [00:17<00:00, 226.13it/s]
# 2026-02-06 20:14:10,102 - INFO - [Epoch 6] Average Loss: 0.502205
# Evaluating: 100%|██████████| 1294/1294 [00:03<00:00, 379.11it/s]
# 2026-02-06 20:14:13,794 - INFO - [Epoch 6] Validation AUC: 0.776468, ACC: 0.722884
# 2026-02-06 20:14:13,800 - INFO - Early stopping triggered at epoch 6.
# 2026-02-06 20:14:13,801 - INFO - --- real_split Best epoch: 5 ---
# 2026-02-06 20:14:13,802 - INFO - Loading best model from real_split for final test evaluation...
# 2026-02-06 20:14:13,807 - INFO - load parameters from paras_EADCD\model_real_real_split.snapshot
# Evaluating: 100%|██████████| 1334/1334 [00:03<00:00, 359.52it/s]
# 2026-02-06 20:14:17,796 - INFO - real_split Test Performance --- AUC: 0.777248, ACC: 0.723093, RMSE: 0.427181, F1: 0.791550
# ==================== Real-Scenario (Time-Series) Split Final Results ====================
# Parameters: train_fraction=1.0, epochs=50, seed=123
# AUC:  0.777248
# ACC:  0.723093
# RMSE: 0.427181
# F1:   0.791550

# %% [markdown]
# # Weak

# %% [markdown]
# ### ASSIST

# %%
runner = ADCD_Runner(
    model_class=MIRT,
    input_dir='../../Data/data/A123',
    split_type='weak',
    train_fraction=1.0,
    **hyperparams
)
runner.run()
# Out:
# 2026-02-06 20:27:54,702 - INFO - Using device: cuda
# 2026-02-06 20:27:54,703 - INFO - Loading metadata and p2k mapping...
# 2026-02-06 20:27:54,710 - INFO - 2493 users, 17676 problems, 123 skills.
# 2026-02-06 20:27:54,718 - INFO - Pre-building global problem Q-matrix...
# 2026-02-06 20:27:55,513 - INFO -
# ==================== Starting Weak-Coverage Split ====================
# 2026-02-06 20:27:56,190 - INFO - weak_split: Train=161155, Val=53719, Test=52549
# 2026-02-06 20:28:00,158 - INFO - Training MIRT (dim=16)... (lr=0.002)
# Epoch 1/50: 100%|██████████| 630/630 [00:03<00:00, 208.51it/s]
# 2026-02-06 20:28:03,185 - INFO - [Epoch 1] Average Loss: 0.609009
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 397.72it/s]
# 2026-02-06 20:28:03,769 - INFO - [Epoch 1] Validation AUC: 0.706753, ACC: 0.696160
# 2026-02-06 20:28:03,772 - INFO - save parameters to paras_EADCD\model_weak_weak_split.snapshot
# 2026-02-06 20:28:03,772 - INFO - Valid improvement (0.706753 > 0.001). Model saved.
# Epoch 2/50: 100%|██████████| 630/630 [00:02<00:00, 244.01it/s]
# 2026-02-06 20:28:06,355 - INFO - [Epoch 2] Average Loss: 0.566224
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 357.37it/s]
# 2026-02-06 20:28:06,990 - INFO - [Epoch 2] Validation AUC: 0.725202, ACC: 0.702880
# 2026-02-06 20:28:06,993 - INFO - save parameters to paras_EADCD\model_weak_weak_split.snapshot
# 2026-02-06 20:28:06,993 - INFO - Valid improvement (0.018449 > 0.001). Model saved.
# Epoch 3/50: 100%|██████████| 630/630 [00:02<00:00, 245.32it/s]
# 2026-02-06 20:28:09,563 - INFO - [Epoch 3] Average Loss: 0.547095
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 340.05it/s]
# 2026-02-06 20:28:10,222 - INFO - [Epoch 3] Validation AUC: 0.738852, ACC: 0.709283
# 2026-02-06 20:28:10,226 - INFO - save parameters to paras_EADCD\model_weak_weak_split.snapshot
# 2026-02-06 20:28:10,227 - INFO - Valid improvement (0.013650 > 0.001). Model saved.
# Epoch 4/50: 100%|██████████| 630/630 [00:02<00:00, 218.63it/s]
# 2026-02-06 20:28:13,112 - INFO - [Epoch 4] Average Loss: 0.531093
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 337.53it/s]
# 2026-02-06 20:28:13,778 - INFO - [Epoch 4] Validation AUC: 0.746573, ACC: 0.712057
# 2026-02-06 20:28:13,781 - INFO - save parameters to paras_EADCD\model_weak_weak_split.snapshot
# 2026-02-06 20:28:13,782 - INFO - Valid improvement (0.007721 > 0.001). Model saved.
# Epoch 5/50: 100%|██████████| 630/630 [00:02<00:00, 218.55it/s]
# 2026-02-06 20:28:16,666 - INFO - [Epoch 5] Average Loss: 0.517277
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 389.29it/s]
# 2026-02-06 20:28:17,252 - INFO - [Epoch 5] Validation AUC: 0.751959, ACC: 0.716804
# 2026-02-06 20:28:17,255 - INFO - save parameters to paras_EADCD\model_weak_weak_split.snapshot
# 2026-02-06 20:28:17,255 - INFO - Valid improvement (0.005387 > 0.001). Model saved.
# Epoch 6/50: 100%|██████████| 630/630 [00:02<00:00, 230.08it/s]
# 2026-02-06 20:28:19,995 - INFO - [Epoch 6] Average Loss: 0.503605
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 424.33it/s]
# 2026-02-06 20:28:20,535 - INFO - [Epoch 6] Validation AUC: 0.758134, ACC: 0.720899
# 2026-02-06 20:28:20,538 - INFO - save parameters to paras_EADCD\model_weak_weak_split.snapshot
# 2026-02-06 20:28:20,538 - INFO - Valid improvement (0.006175 > 0.001). Model saved.
# Epoch 7/50: 100%|██████████| 630/630 [00:02<00:00, 228.60it/s]
# 2026-02-06 20:28:23,297 - INFO - [Epoch 7] Average Loss: 0.488966
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 420.76it/s]
# 2026-02-06 20:28:23,841 - INFO - [Epoch 7] Validation AUC: 0.763559, ACC: 0.724697
# 2026-02-06 20:28:23,844 - INFO - save parameters to paras_EADCD\model_weak_weak_split.snapshot
# 2026-02-06 20:28:23,844 - INFO - Valid improvement (0.005425 > 0.001). Model saved.
# Epoch 8/50: 100%|██████████| 630/630 [00:02<00:00, 231.93it/s]
# 2026-02-06 20:28:26,561 - INFO - [Epoch 8] Average Loss: 0.472652
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 403.86it/s]
# 2026-02-06 20:28:27,128 - INFO - [Epoch 8] Validation AUC: 0.768178, ACC: 0.728271
# 2026-02-06 20:28:27,131 - INFO - save parameters to paras_EADCD\model_weak_weak_split.snapshot
# 2026-02-06 20:28:27,131 - INFO - Valid improvement (0.004619 > 0.001). Model saved.
# Epoch 9/50: 100%|██████████| 630/630 [00:02<00:00, 224.31it/s]
# 2026-02-06 20:28:29,943 - INFO - [Epoch 9] Average Loss: 0.454457
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 367.10it/s]
# 2026-02-06 20:28:30,564 - INFO - [Epoch 9] Validation AUC: 0.772810, ACC: 0.731212
# 2026-02-06 20:28:30,568 - INFO - save parameters to paras_EADCD\model_weak_weak_split.snapshot
# 2026-02-06 20:28:30,568 - INFO - Valid improvement (0.004632 > 0.001). Model saved.
# Epoch 10/50: 100%|██████████| 630/630 [00:02<00:00, 232.54it/s]
# 2026-02-06 20:28:33,281 - INFO - [Epoch 10] Average Loss: 0.434244
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 359.35it/s]
# 2026-02-06 20:28:33,910 - INFO - [Epoch 10] Validation AUC: 0.778192, ACC: 0.734489
# 2026-02-06 20:28:33,915 - INFO - save parameters to paras_EADCD\model_weak_weak_split.snapshot
# 2026-02-06 20:28:33,915 - INFO - Valid improvement (0.005382 > 0.001). Model saved.
# Epoch 11/50: 100%|██████████| 630/630 [00:02<00:00, 248.00it/s]
# 2026-02-06 20:28:36,456 - INFO - [Epoch 11] Average Loss: 0.412322
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 359.47it/s]
# 2026-02-06 20:28:37,085 - INFO - [Epoch 11] Validation AUC: 0.782595, ACC: 0.737858
# 2026-02-06 20:28:37,088 - INFO - save parameters to paras_EADCD\model_weak_weak_split.snapshot
# 2026-02-06 20:28:37,088 - INFO - Valid improvement (0.004402 > 0.001). Model saved.
# Epoch 12/50: 100%|██████████| 630/630 [00:02<00:00, 248.08it/s]
# 2026-02-06 20:28:39,630 - INFO - [Epoch 12] Average Loss: 0.389600
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 356.39it/s]
# 2026-02-06 20:28:40,267 - INFO - [Epoch 12] Validation AUC: 0.786500, ACC: 0.739496
# 2026-02-06 20:28:40,270 - INFO - save parameters to paras_EADCD\model_weak_weak_split.snapshot
# 2026-02-06 20:28:40,270 - INFO - Valid improvement (0.003905 > 0.001). Model saved.
# Epoch 13/50: 100%|██████████| 630/630 [00:02<00:00, 250.30it/s]
# 2026-02-06 20:28:42,790 - INFO - [Epoch 13] Average Loss: 0.366334
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 362.66it/s]
# 2026-02-06 20:28:43,410 - INFO - [Epoch 13] Validation AUC: 0.789091, ACC: 0.739775
# 2026-02-06 20:28:43,414 - INFO - save parameters to paras_EADCD\model_weak_weak_split.snapshot
# 2026-02-06 20:28:43,414 - INFO - Valid improvement (0.002591 > 0.001). Model saved.
# Epoch 14/50: 100%|██████████| 630/630 [00:02<00:00, 241.38it/s]
# 2026-02-06 20:28:46,024 - INFO - [Epoch 14] Average Loss: 0.343431
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 415.24it/s]
# 2026-02-06 20:28:46,578 - INFO - [Epoch 14] Validation AUC: 0.791264, ACC: 0.742233
# 2026-02-06 20:28:46,580 - INFO - save parameters to paras_EADCD\model_weak_weak_split.snapshot
# 2026-02-06 20:28:46,580 - INFO - Valid improvement (0.002173 > 0.001). Model saved.
# Epoch 15/50: 100%|██████████| 630/630 [00:02<00:00, 229.50it/s]
# 2026-02-06 20:28:49,326 - INFO - [Epoch 15] Average Loss: 0.320929
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 417.30it/s]
# 2026-02-06 20:28:49,875 - INFO - [Epoch 15] Validation AUC: 0.791723, ACC: 0.743666
# 2026-02-06 20:28:49,876 - INFO - Early stopping triggered at epoch 15.
# 2026-02-06 20:28:49,877 - INFO - --- weak_split Best epoch: 14 ---
# 2026-02-06 20:28:49,877 - INFO - Loading best model from weak_split for final test evaluation...
# 2026-02-06 20:28:49,908 - INFO - load parameters from paras_EADCD\model_weak_weak_split.snapshot
# Evaluating: 100%|██████████| 206/206 [00:00<00:00, 397.78it/s]
# 2026-02-06 20:28:50,477 - INFO - weak_split Test Performance --- AUC: 0.717273, ACC: 0.719633, RMSE: 0.434566, F1: 0.806732
# ==================== Weak-Coverage Split Final Results ====================
# Parameters: train_fraction=1.0, epochs=50, seed=123
# AUC:  0.717273
# ACC:  0.719633
# RMSE: 0.434566
# F1:   0.806732

# %% [markdown]
# ### junyi

# %%
runner = ADCD_Runner(
    model_class=MIRT,
    input_dir='../../Data/data/J123',
    split_type='weak',
    train_fraction=1.0,
    **hyperparams
)
runner.run()
# Out:
# 2026-02-06 20:15:43,864 - INFO - Using device: cuda
# 2026-02-06 20:15:43,865 - INFO - Loading metadata and p2k mapping...
# 2026-02-06 20:15:43,867 - INFO - 10000 users, 675 problems, 510 skills.
# 2026-02-06 20:15:43,867 - INFO - Pre-building global problem Q-matrix...
# 2026-02-06 20:15:43,912 - INFO -
# ==================== Starting Weak-Coverage Split ====================
# 2026-02-06 20:15:47,378 - INFO - weak_split: Train=248586, Val=82862, Test=78170
# 2026-02-06 20:16:09,790 - INFO - Training MIRT (dim=16)... (lr=0.002)
# Epoch 1/50: 100%|██████████| 972/972 [00:04<00:00, 196.27it/s]
# 2026-02-06 20:16:14,746 - INFO - [Epoch 1] Average Loss: 0.562658
# Evaluating: 100%|██████████| 324/324 [00:00<00:00, 395.02it/s]
# 2026-02-06 20:16:15,633 - INFO - [Epoch 1] Validation AUC: 0.787377, ACC: 0.741486
# 2026-02-06 20:16:15,642 - INFO - save parameters to paras_EADCD\model_weak_weak_split.snapshot
# 2026-02-06 20:16:15,643 - INFO - Valid improvement (0.787377 > 0.001). Model saved.
# Epoch 2/50: 100%|██████████| 972/972 [00:04<00:00, 203.02it/s]
# 2026-02-06 20:16:20,433 - INFO - [Epoch 2] Average Loss: 0.490220
# Evaluating: 100%|██████████| 324/324 [00:00<00:00, 399.45it/s]
# 2026-02-06 20:16:21,311 - INFO - [Epoch 2] Validation AUC: 0.800063, ACC: 0.757078
# 2026-02-06 20:16:21,314 - INFO - save parameters to paras_EADCD\model_weak_weak_split.snapshot
# 2026-02-06 20:16:21,315 - INFO - Valid improvement (0.012686 > 0.001). Model saved.
# Epoch 3/50: 100%|██████████| 972/972 [00:04<00:00, 214.36it/s]
# 2026-02-06 20:16:25,853 - INFO - [Epoch 3] Average Loss: 0.473441
# Evaluating: 100%|██████████| 324/324 [00:00<00:00, 385.12it/s]
# 2026-02-06 20:16:26,762 - INFO - [Epoch 3] Validation AUC: 0.805423, ACC: 0.764609
# 2026-02-06 20:16:26,764 - INFO - save parameters to paras_EADCD\model_weak_weak_split.snapshot
# 2026-02-06 20:16:26,765 - INFO - Valid improvement (0.005360 > 0.001). Model saved.
# Epoch 4/50: 100%|██████████| 972/972 [00:04<00:00, 197.04it/s]
# 2026-02-06 20:16:31,700 - INFO - [Epoch 4] Average Loss: 0.464397
# Evaluating: 100%|██████████| 324/324 [00:00<00:00, 343.52it/s]
# 2026-02-06 20:16:32,712 - INFO - [Epoch 4] Validation AUC: 0.808046, ACC: 0.766491
# 2026-02-06 20:16:32,716 - INFO - save parameters to paras_EADCD\model_weak_weak_split.snapshot
# 2026-02-06 20:16:32,717 - INFO - Valid improvement (0.002622 > 0.001). Model saved.
# Epoch 5/50: 100%|██████████| 972/972 [00:04<00:00, 202.89it/s]
# 2026-02-06 20:16:37,509 - INFO - [Epoch 5] Average Loss: 0.458224
# Evaluating: 100%|██████████| 324/324 [00:00<00:00, 337.19it/s]
# 2026-02-06 20:16:38,546 - INFO - [Epoch 5] Validation AUC: 0.809681, ACC: 0.768326
# 2026-02-06 20:16:38,549 - INFO - save parameters to paras_EADCD\model_weak_weak_split.snapshot
# 2026-02-06 20:16:38,550 - INFO - Valid improvement (0.001636 > 0.001). Model saved.
# Epoch 6/50: 100%|██████████| 972/972 [00:05<00:00, 185.81it/s]
# 2026-02-06 20:16:43,783 - INFO - [Epoch 6] Average Loss: 0.452539
# Evaluating: 100%|██████████| 324/324 [00:01<00:00, 321.19it/s]
# 2026-02-06 20:16:44,883 - INFO - [Epoch 6] Validation AUC: 0.810395, ACC: 0.768676
# 2026-02-06 20:16:44,884 - INFO - Early stopping triggered at epoch 6.
# 2026-02-06 20:16:44,884 - INFO - --- weak_split Best epoch: 5 ---
# 2026-02-06 20:16:44,885 - INFO - Loading best model from weak_split for final test evaluation...
# 2026-02-06 20:16:44,919 - INFO - load parameters from paras_EADCD\model_weak_weak_split.snapshot
# Evaluating: 100%|██████████| 306/306 [00:00<00:00, 342.79it/s]
# 2026-02-06 20:16:45,877 - INFO - weak_split Test Performance --- AUC: 0.737435, ACC: 0.713535, RMSE: 0.436265, F1: 0.795406
# ==================== Weak-Coverage Split Final Results ====================
# Parameters: train_fraction=1.0, epochs=50, seed=123
# AUC:  0.737435
# ACC:  0.713535
# RMSE: 0.436265
# F1:   0.795406

# %% [markdown]
# ### NIPS

# %%
runner = ADCD_Runner(
    model_class=MIRT,
    input_dir='../../Data/data/N123',
    split_type='weak',
    train_fraction=1.0,
    **hyperparams
)
runner.run()
# Out:
# 2026-02-06 20:57:48,278 - INFO - Using device: cuda
# 2026-02-06 20:57:48,290 - INFO - Loading metadata and p2k mapping...
# 2026-02-06 20:57:48,338 - INFO - 10000 users, 27599 problems, 388 skills.
# 2026-02-06 20:57:48,369 - INFO - Pre-building global problem Q-matrix...
# 2026-02-06 20:57:49,711 - INFO -
# ==================== Starting Weak-Coverage Split ====================
# 2026-02-06 20:58:01,921 - INFO - weak_split: Train=1005756, Val=335253, Test=331031
# 2026-02-06 20:59:16,837 - INFO - Training MIRT (dim=16)... (lr=0.002)
# Epoch 1/50: 100%|██████████| 3929/3929 [00:20<00:00, 194.49it/s]
# 2026-02-06 20:59:37,064 - INFO - [Epoch 1] Average Loss: 0.572596
# Evaluating: 100%|██████████| 1310/1310 [00:03<00:00, 351.58it/s]
# 2026-02-06 20:59:41,086 - INFO - [Epoch 1] Validation AUC: 0.760279, ACC: 0.711815
# 2026-02-06 20:59:41,098 - INFO - save parameters to paras_EADCD\model_weak_weak_split.snapshot
# 2026-02-06 20:59:41,098 - INFO - Valid improvement (0.760279 > 0.001). Model saved.
# Epoch 2/50: 100%|██████████| 3929/3929 [00:18<00:00, 217.46it/s]
# 2026-02-06 20:59:59,169 - INFO - [Epoch 2] Average Loss: 0.536073
# Evaluating: 100%|██████████| 1310/1310 [00:03<00:00, 328.46it/s]
# 2026-02-06 21:00:03,475 - INFO - [Epoch 2] Validation AUC: 0.773412, ACC: 0.721849
# 2026-02-06 21:00:03,483 - INFO - save parameters to paras_EADCD\model_weak_weak_split.snapshot
# 2026-02-06 21:00:03,484 - INFO - Valid improvement (0.013133 > 0.001). Model saved.
# Epoch 3/50: 100%|██████████| 3929/3929 [00:18<00:00, 209.82it/s]
# 2026-02-06 21:00:22,213 - INFO - [Epoch 3] Average Loss: 0.523882
# Evaluating: 100%|██████████| 1310/1310 [00:03<00:00, 362.83it/s]
# 2026-02-06 21:00:26,130 - INFO - [Epoch 3] Validation AUC: 0.777418, ACC: 0.725351
# 2026-02-06 21:00:26,137 - INFO - save parameters to paras_EADCD\model_weak_weak_split.snapshot
# 2026-02-06 21:00:26,138 - INFO - Valid improvement (0.004006 > 0.001). Model saved.
# Epoch 4/50: 100%|██████████| 3929/3929 [00:18<00:00, 210.44it/s]
# 2026-02-06 21:00:44,813 - INFO - [Epoch 4] Average Loss: 0.516484
# Evaluating: 100%|██████████| 1310/1310 [00:03<00:00, 360.41it/s]
# 2026-02-06 21:00:48,743 - INFO - [Epoch 4] Validation AUC: 0.779599, ACC: 0.726887
# 2026-02-06 21:00:48,750 - INFO - save parameters to paras_EADCD\model_weak_weak_split.snapshot
# 2026-02-06 21:00:48,752 - INFO - Valid improvement (0.002181 > 0.001). Model saved.
# Epoch 5/50: 100%|██████████| 3929/3929 [00:18<00:00, 215.35it/s]
# 2026-02-06 21:01:06,999 - INFO - [Epoch 5] Average Loss: 0.508988
# Evaluating: 100%|██████████| 1310/1310 [00:03<00:00, 367.92it/s]
# 2026-02-06 21:01:10,853 - INFO - [Epoch 5] Validation AUC: 0.780412, ACC: 0.727477
# 2026-02-06 21:01:10,853 - INFO - Early stopping triggered at epoch 5.
# 2026-02-06 21:01:10,853 - INFO - --- weak_split Best epoch: 4 ---
# 2026-02-06 21:01:10,853 - INFO - Loading best model from weak_split for final test evaluation...
# 2026-02-06 21:01:10,869 - INFO - load parameters from paras_EADCD\model_weak_weak_split.snapshot
# Evaluating: 100%|██████████| 1294/1294 [00:03<00:00, 350.44it/s]
# 2026-02-06 21:01:14,879 - INFO - weak_split Test Performance --- AUC: 0.748548, ACC: 0.697412, RMSE: 0.445002, F1: 0.771608
# ==================== Weak-Coverage Split Final Results ====================
# Parameters: train_fraction=1.0, epochs=50, seed=123
# AUC:  0.748548
# ACC:  0.697412
# RMSE: 0.445002
# F1:   0.771608

# %% [markdown]
# # Random

# %% [markdown]
# ### ASSIST

# %% [markdown]
# **100% train**

# %%
runner = ADCD_Runner(
    model_class=MIRT,
    input_dir='../../Data/data/A123',
    split_type='random',
    train_fraction=1.0,
    **hyperparams
)
runner.run()
# Out:
# 2026-02-06 21:01:15,963 - INFO - Using device: cuda
# 2026-02-06 21:01:15,968 - INFO - Loading metadata and p2k mapping...
# 2026-02-06 21:01:15,977 - INFO - 2493 users, 17676 problems, 123 skills.
# 2026-02-06 21:01:15,991 - INFO - Pre-building global problem Q-matrix...
# 2026-02-06 21:01:16,745 - INFO -
# ==================== Starting Random Split Fold 1/5 ====================
# 2026-02-06 21:01:17,421 - INFO - random_fold_1: Train=159708, Val=53236, Test=54479
# 2026-02-06 21:01:21,415 - INFO - Training MIRT (dim=16)... (lr=0.002)
# Epoch 1/50: 100%|██████████| 624/624 [00:02<00:00, 232.20it/s]
# 2026-02-06 21:01:24,108 - INFO - [Epoch 1] Average Loss: 0.604907
# Evaluating: 100%|██████████| 208/208 [00:00<00:00, 359.82it/s]
# 2026-02-06 21:01:24,729 - INFO - [Epoch 1] Validation AUC: 0.703429, ACC: 0.699808
# 2026-02-06 21:01:24,735 - INFO - save parameters to paras_EADCD\model_random_random_fold_1.snapshot
# 2026-02-06 21:01:24,736 - INFO - Valid improvement (0.703429 > 0.001). Model saved.
# Epoch 2/50: 100%|██████████| 624/624 [00:02<00:00, 273.92it/s]
# 2026-02-06 21:01:27,015 - INFO - [Epoch 2] Average Loss: 0.561408
# Evaluating: 100%|██████████| 208/208 [00:00<00:00, 358.73it/s]
# 2026-02-06 21:01:27,638 - INFO - [Epoch 2] Validation AUC: 0.723840, ACC: 0.704843
# 2026-02-06 21:01:27,643 - INFO - save parameters to paras_EADCD\model_random_random_fold_1.snapshot
# 2026-02-06 21:01:27,643 - INFO - Valid improvement (0.020411 > 0.001). Model saved.
# Epoch 3/50: 100%|██████████| 624/624 [00:02<00:00, 240.56it/s]
# 2026-02-06 21:01:30,250 - INFO - [Epoch 3] Average Loss: 0.542159
# Evaluating: 100%|██████████| 208/208 [00:00<00:00, 417.74it/s]
# 2026-02-06 21:01:30,789 - INFO - [Epoch 3] Validation AUC: 0.736541, ACC: 0.711192
# 2026-02-06 21:01:30,796 - INFO - save parameters to paras_EADCD\model_random_random_fold_1.snapshot
# 2026-02-06 21:01:30,796 - INFO - Valid improvement (0.012701 > 0.001). Model saved.
# Epoch 4/50: 100%|██████████| 624/624 [00:02<00:00, 233.94it/s]
# 2026-02-06 21:01:33,463 - INFO - [Epoch 4] Average Loss: 0.526610
# Evaluating: 100%|██████████| 208/208 [00:00<00:00, 352.67it/s]
# 2026-02-06 21:01:34,102 - INFO - [Epoch 4] Validation AUC: 0.745172, ACC: 0.715662
# 2026-02-06 21:01:34,105 - INFO - save parameters to paras_EADCD\model_random_random_fold_1.snapshot
# 2026-02-06 21:01:34,105 - INFO - Valid improvement (0.008631 > 0.001). Model saved.
# Epoch 5/50: 100%|██████████| 624/624 [00:02<00:00, 250.49it/s]
# 2026-02-06 21:01:36,599 - INFO - [Epoch 5] Average Loss: 0.512626
# Evaluating: 100%|██████████| 208/208 [00:00<00:00, 346.11it/s]
# 2026-02-06 21:01:37,236 - INFO - [Epoch 5] Validation AUC: 0.750936, ACC: 0.720171
# 2026-02-06 21:01:37,246 - INFO - save parameters to paras_EADCD\model_random_random_fold_1.snapshot
# 2026-02-06 21:01:37,246 - INFO - Valid improvement (0.005764 > 0.001). Model saved.
# Epoch 6/50: 100%|██████████| 624/624 [00:02<00:00, 242.87it/s]
# 2026-02-06 21:01:39,815 - INFO - [Epoch 6] Average Loss: 0.498990
# Evaluating: 100%|██████████| 208/208 [00:00<00:00, 419.02it/s]
# 2026-02-06 21:01:40,353 - INFO - [Epoch 6] Validation AUC: 0.755194, ACC: 0.724247
# 2026-02-06 21:01:40,357 - INFO - save parameters to paras_EADCD\model_random_random_fold_1.snapshot
# 2026-02-06 21:01:40,357 - INFO - Valid improvement (0.004258 > 0.001). Model saved.
# Epoch 7/50: 100%|██████████| 624/624 [00:02<00:00, 239.38it/s]
# 2026-02-06 21:01:42,970 - INFO - [Epoch 7] Average Loss: 0.484907
# Evaluating: 100%|██████████| 208/208 [00:00<00:00, 346.86it/s]
# 2026-02-06 21:01:43,612 - INFO - [Epoch 7] Validation AUC: 0.759661, ACC: 0.727684
# 2026-02-06 21:01:43,615 - INFO - save parameters to paras_EADCD\model_random_random_fold_1.snapshot
# 2026-02-06 21:01:43,616 - INFO - Valid improvement (0.004467 > 0.001). Model saved.
# Epoch 8/50: 100%|██████████| 624/624 [00:02<00:00, 241.87it/s]
# 2026-02-06 21:01:46,197 - INFO - [Epoch 8] Average Loss: 0.469210
# Evaluating: 100%|██████████| 208/208 [00:00<00:00, 337.24it/s]
# 2026-02-06 21:01:46,860 - INFO - [Epoch 8] Validation AUC: 0.763505, ACC: 0.730577
# 2026-02-06 21:01:46,863 - INFO - save parameters to paras_EADCD\model_random_random_fold_1.snapshot
# 2026-02-06 21:01:46,863 - INFO - Valid improvement (0.003844 > 0.001). Model saved.
# Epoch 9/50: 100%|██████████| 624/624 [00:02<00:00, 233.67it/s]
# 2026-02-06 21:01:49,537 - INFO - [Epoch 9] Average Loss: 0.451624
# Evaluating: 100%|██████████| 208/208 [00:00<00:00, 417.05it/s]
# 2026-02-06 21:01:50,082 - INFO - [Epoch 9] Validation AUC: 0.767910, ACC: 0.733357
# 2026-02-06 21:01:50,085 - INFO - save parameters to paras_EADCD\model_random_random_fold_1.snapshot
# 2026-02-06 21:01:50,085 - INFO - Valid improvement (0.004405 > 0.001). Model saved.
# Epoch 10/50: 100%|██████████| 624/624 [00:02<00:00, 240.28it/s]
# 2026-02-06 21:01:52,683 - INFO - [Epoch 10] Average Loss: 0.432090
# Evaluating: 100%|██████████| 208/208 [00:00<00:00, 361.03it/s]
# 2026-02-06 21:01:53,304 - INFO - [Epoch 10] Validation AUC: 0.771105, ACC: 0.734710
# 2026-02-06 21:01:53,307 - INFO - save parameters to paras_EADCD\model_random_random_fold_1.snapshot
# 2026-02-06 21:01:53,307 - INFO - Valid improvement (0.003194 > 0.001). Model saved.
# Epoch 11/50: 100%|██████████| 624/624 [00:02<00:00, 239.37it/s]
# 2026-02-06 21:01:55,916 - INFO - [Epoch 11] Average Loss: 0.410869
# Evaluating: 100%|██████████| 208/208 [00:00<00:00, 413.71it/s]
# 2026-02-06 21:01:56,453 - INFO - [Epoch 11] Validation AUC: 0.774672, ACC: 0.738260
# 2026-02-06 21:01:56,463 - INFO - save parameters to paras_EADCD\model_random_random_fold_1.snapshot
# 2026-02-06 21:01:56,463 - INFO - Valid improvement (0.003568 > 0.001). Model saved.
# Epoch 12/50: 100%|██████████| 624/624 [00:02<00:00, 241.89it/s]
# 2026-02-06 21:01:59,048 - INFO - [Epoch 12] Average Loss: 0.388423
# Evaluating: 100%|██████████| 208/208 [00:00<00:00, 426.83it/s]
# 2026-02-06 21:01:59,585 - INFO - [Epoch 12] Validation AUC: 0.777517, ACC: 0.740345
# 2026-02-06 21:01:59,588 - INFO - save parameters to paras_EADCD\model_random_random_fold_1.snapshot
# 2026-02-06 21:01:59,588 - INFO - Valid improvement (0.002845 > 0.001). Model saved.
# Epoch 13/50: 100%|██████████| 624/624 [00:02<00:00, 230.40it/s]
# 2026-02-06 21:02:02,298 - INFO - [Epoch 13] Average Loss: 0.365352
# Evaluating: 100%|██████████| 208/208 [00:00<00:00, 388.28it/s]
# 2026-02-06 21:02:02,881 - INFO - [Epoch 13] Validation AUC: 0.778914, ACC: 0.740777
# 2026-02-06 21:02:02,884 - INFO - save parameters to paras_EADCD\model_random_random_fold_1.snapshot
# 2026-02-06 21:02:02,884 - INFO - Valid improvement (0.001398 > 0.001). Model saved.
# Epoch 14/50: 100%|██████████| 624/624 [00:02<00:00, 242.33it/s]
# 2026-02-06 21:02:05,461 - INFO - [Epoch 14] Average Loss: 0.342187
# Evaluating: 100%|██████████| 208/208 [00:00<00:00, 421.38it/s]
# 2026-02-06 21:02:05,998 - INFO - [Epoch 14] Validation AUC: 0.779592, ACC: 0.740251
# 2026-02-06 21:02:06,000 - INFO - Early stopping triggered at epoch 14.
# 2026-02-06 21:02:06,001 - INFO - --- random_fold_1 Best epoch: 13 ---
# 2026-02-06 21:02:06,001 - INFO - Loading best model from random_fold_1 for final test evaluation...
# 2026-02-06 21:02:06,034 - INFO - load parameters from paras_EADCD\model_random_random_fold_1.snapshot
# Evaluating: 100%|██████████| 213/213 [00:00<00:00, 359.39it/s]
# 2026-02-06 21:02:06,669 - INFO - random_fold_1 Test Performance --- AUC: 0.779493, ACC: 0.741056, RMSE: 0.418153, F1: 0.816160
# 2026-02-06 21:02:06,689 - INFO -
# ==================== Starting Random Split Fold 2/5 ====================
# 2026-02-06 21:02:07,373 - INFO - random_fold_2: Train=160112, Val=53371, Test=53940
# 2026-02-06 21:02:11,222 - INFO - Training MIRT (dim=16)... (lr=0.002)
# Epoch 1/50: 100%|██████████| 626/626 [00:02<00:00, 227.75it/s]
# 2026-02-06 21:02:13,974 - INFO - [Epoch 1] Average Loss: 0.602966
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 393.47it/s]
# 2026-02-06 21:02:14,546 - INFO - [Epoch 1] Validation AUC: 0.701514, ACC: 0.701055
# 2026-02-06 21:02:14,546 - INFO - save parameters to paras_EADCD\model_random_random_fold_2.snapshot
# 2026-02-06 21:02:14,546 - INFO - Valid improvement (0.701514 > 0.001). Model saved.
# Epoch 2/50: 100%|██████████| 626/626 [00:02<00:00, 245.69it/s]
# 2026-02-06 21:02:17,102 - INFO - [Epoch 2] Average Loss: 0.558888
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 423.68it/s]
# 2026-02-06 21:02:17,639 - INFO - [Epoch 2] Validation AUC: 0.719930, ACC: 0.704446
# 2026-02-06 21:02:17,643 - INFO - save parameters to paras_EADCD\model_random_random_fold_2.snapshot
# 2026-02-06 21:02:17,644 - INFO - Valid improvement (0.018416 > 0.001). Model saved.
# Epoch 3/50: 100%|██████████| 626/626 [00:02<00:00, 233.72it/s]
# 2026-02-06 21:02:20,324 - INFO - [Epoch 3] Average Loss: 0.539434
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 349.05it/s]
# 2026-02-06 21:02:20,966 - INFO - [Epoch 3] Validation AUC: 0.732501, ACC: 0.709917
# 2026-02-06 21:02:20,969 - INFO - save parameters to paras_EADCD\model_random_random_fold_2.snapshot
# 2026-02-06 21:02:20,969 - INFO - Valid improvement (0.012571 > 0.001). Model saved.
# Epoch 4/50: 100%|██████████| 626/626 [00:02<00:00, 232.98it/s]
# 2026-02-06 21:02:23,656 - INFO - [Epoch 4] Average Loss: 0.523725
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 350.56it/s]
# 2026-02-06 21:02:24,300 - INFO - [Epoch 4] Validation AUC: 0.740581, ACC: 0.715182
# 2026-02-06 21:02:24,304 - INFO - save parameters to paras_EADCD\model_random_random_fold_2.snapshot
# 2026-02-06 21:02:24,305 - INFO - Valid improvement (0.008080 > 0.001). Model saved.
# Epoch 5/50: 100%|██████████| 626/626 [00:02<00:00, 239.53it/s]
# 2026-02-06 21:02:26,919 - INFO - [Epoch 5] Average Loss: 0.509578
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 417.95it/s]
# 2026-02-06 21:02:27,453 - INFO - [Epoch 5] Validation AUC: 0.746495, ACC: 0.718874
# 2026-02-06 21:02:27,462 - INFO - save parameters to paras_EADCD\model_random_random_fold_2.snapshot
# 2026-02-06 21:02:27,462 - INFO - Valid improvement (0.005914 > 0.001). Model saved.
# Epoch 6/50: 100%|██████████| 626/626 [00:02<00:00, 214.61it/s]
# 2026-02-06 21:02:30,379 - INFO - [Epoch 6] Average Loss: 0.496252
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 414.33it/s]
# 2026-02-06 21:02:30,929 - INFO - [Epoch 6] Validation AUC: 0.751411, ACC: 0.722508
# 2026-02-06 21:02:30,929 - INFO - save parameters to paras_EADCD\model_random_random_fold_2.snapshot
# 2026-02-06 21:02:30,929 - INFO - Valid improvement (0.004916 > 0.001). Model saved.
# Epoch 7/50: 100%|██████████| 626/626 [00:02<00:00, 225.20it/s]
# 2026-02-06 21:02:33,716 - INFO - [Epoch 7] Average Loss: 0.482037
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 351.52it/s]
# 2026-02-06 21:02:34,353 - INFO - [Epoch 7] Validation AUC: 0.755122, ACC: 0.725919
# 2026-02-06 21:02:34,353 - INFO - save parameters to paras_EADCD\model_random_random_fold_2.snapshot
# 2026-02-06 21:02:34,353 - INFO - Valid improvement (0.003711 > 0.001). Model saved.
# Epoch 8/50: 100%|██████████| 626/626 [00:02<00:00, 243.88it/s]
# 2026-02-06 21:02:36,920 - INFO - [Epoch 8] Average Loss: 0.466750
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 358.48it/s]
# 2026-02-06 21:02:37,543 - INFO - [Epoch 8] Validation AUC: 0.759349, ACC: 0.729685
# 2026-02-06 21:02:37,545 - INFO - save parameters to paras_EADCD\model_random_random_fold_2.snapshot
# 2026-02-06 21:02:37,546 - INFO - Valid improvement (0.004227 > 0.001). Model saved.
# Epoch 9/50: 100%|██████████| 626/626 [00:02<00:00, 232.76it/s]
# 2026-02-06 21:02:40,238 - INFO - [Epoch 9] Average Loss: 0.449270
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 426.41it/s]
# 2026-02-06 21:02:40,773 - INFO - [Epoch 9] Validation AUC: 0.763315, ACC: 0.731165
# 2026-02-06 21:02:40,777 - INFO - save parameters to paras_EADCD\model_random_random_fold_2.snapshot
# 2026-02-06 21:02:40,778 - INFO - Valid improvement (0.003966 > 0.001). Model saved.
# Epoch 10/50: 100%|██████████| 626/626 [00:02<00:00, 227.04it/s]
# 2026-02-06 21:02:43,536 - INFO - [Epoch 10] Average Loss: 0.430215
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 408.39it/s]
# 2026-02-06 21:02:44,090 - INFO - [Epoch 10] Validation AUC: 0.767482, ACC: 0.732514
# 2026-02-06 21:02:44,093 - INFO - save parameters to paras_EADCD\model_random_random_fold_2.snapshot
# 2026-02-06 21:02:44,094 - INFO - Valid improvement (0.004168 > 0.001). Model saved.
# Epoch 11/50: 100%|██████████| 626/626 [00:02<00:00, 235.70it/s]
# 2026-02-06 21:02:46,751 - INFO - [Epoch 11] Average Loss: 0.409325
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 410.38it/s]
# 2026-02-06 21:02:47,303 - INFO - [Epoch 11] Validation AUC: 0.770144, ACC: 0.734575
# 2026-02-06 21:02:47,303 - INFO - save parameters to paras_EADCD\model_random_random_fold_2.snapshot
# 2026-02-06 21:02:47,303 - INFO - Valid improvement (0.002661 > 0.001). Model saved.
# Epoch 12/50: 100%|██████████| 626/626 [00:02<00:00, 237.99it/s]
# 2026-02-06 21:02:49,934 - INFO - [Epoch 12] Average Loss: 0.387428
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 362.54it/s]
# 2026-02-06 21:02:50,555 - INFO - [Epoch 12] Validation AUC: 0.773200, ACC: 0.737741
# 2026-02-06 21:02:50,558 - INFO - save parameters to paras_EADCD\model_random_random_fold_2.snapshot
# 2026-02-06 21:02:50,558 - INFO - Valid improvement (0.003057 > 0.001). Model saved.
# Epoch 13/50: 100%|██████████| 626/626 [00:02<00:00, 241.43it/s]
# 2026-02-06 21:02:53,153 - INFO - [Epoch 13] Average Loss: 0.364712
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 416.13it/s]
# 2026-02-06 21:02:53,696 - INFO - [Epoch 13] Validation AUC: 0.775151, ACC: 0.738210
# 2026-02-06 21:02:53,696 - INFO - save parameters to paras_EADCD\model_random_random_fold_2.snapshot
# 2026-02-06 21:02:53,701 - INFO - Valid improvement (0.001951 > 0.001). Model saved.
# Epoch 14/50: 100%|██████████| 626/626 [00:02<00:00, 228.18it/s]
# 2026-02-06 21:02:56,446 - INFO - [Epoch 14] Average Loss: 0.341860
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 408.44it/s]
# 2026-02-06 21:02:56,999 - INFO - [Epoch 14] Validation AUC: 0.776534, ACC: 0.738828
# 2026-02-06 21:02:57,002 - INFO - save parameters to paras_EADCD\model_random_random_fold_2.snapshot
# 2026-02-06 21:02:57,003 - INFO - Valid improvement (0.001383 > 0.001). Model saved.
# Epoch 15/50: 100%|██████████| 626/626 [00:02<00:00, 237.75it/s]
# 2026-02-06 21:02:59,636 - INFO - [Epoch 15] Average Loss: 0.319400
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 410.23it/s]
# 2026-02-06 21:03:00,187 - INFO - [Epoch 15] Validation AUC: 0.777163, ACC: 0.739147
# 2026-02-06 21:03:00,187 - INFO - Early stopping triggered at epoch 15.
# 2026-02-06 21:03:00,188 - INFO - --- random_fold_2 Best epoch: 14 ---
# 2026-02-06 21:03:00,188 - INFO - Loading best model from random_fold_2 for final test evaluation...
# 2026-02-06 21:03:00,219 - INFO - load parameters from paras_EADCD\model_random_random_fold_2.snapshot
# Evaluating: 100%|██████████| 211/211 [00:00<00:00, 363.21it/s]
# 2026-02-06 21:03:00,853 - INFO - random_fold_2 Test Performance --- AUC: 0.777066, ACC: 0.738821, RMSE: 0.421421, F1: 0.813221
# 2026-02-06 21:03:00,860 - INFO -
# ==================== Starting Random Split Fold 3/5 ====================
# 2026-02-06 21:03:01,560 - INFO - random_fold_3: Train=160484, Val=53495, Test=53444
# 2026-02-06 21:03:05,403 - INFO - Training MIRT (dim=16)... (lr=0.002)
# Epoch 1/50: 100%|██████████| 627/627 [00:02<00:00, 225.93it/s]
# 2026-02-06 21:03:08,183 - INFO - [Epoch 1] Average Loss: 0.603560
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 421.45it/s]
# 2026-02-06 21:03:08,719 - INFO - [Epoch 1] Validation AUC: 0.705251, ACC: 0.699617
# 2026-02-06 21:03:08,738 - INFO - save parameters to paras_EADCD\model_random_random_fold_3.snapshot
# 2026-02-06 21:03:08,739 - INFO - Valid improvement (0.705251 > 0.001). Model saved.
# Epoch 2/50: 100%|██████████| 627/627 [00:02<00:00, 259.92it/s]
# 2026-02-06 21:03:11,153 - INFO - [Epoch 2] Average Loss: 0.560354
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 354.36it/s]
# 2026-02-06 21:03:11,784 - INFO - [Epoch 2] Validation AUC: 0.724189, ACC: 0.707225
# 2026-02-06 21:03:11,788 - INFO - save parameters to paras_EADCD\model_random_random_fold_3.snapshot
# 2026-02-06 21:03:11,788 - INFO - Valid improvement (0.018938 > 0.001). Model saved.
# Epoch 3/50: 100%|██████████| 627/627 [00:02<00:00, 238.67it/s]
# 2026-02-06 21:03:14,415 - INFO - [Epoch 3] Average Loss: 0.541105
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 416.32it/s]
# 2026-02-06 21:03:14,963 - INFO - [Epoch 3] Validation AUC: 0.734527, ACC: 0.711020
# 2026-02-06 21:03:14,963 - INFO - save parameters to paras_EADCD\model_random_random_fold_3.snapshot
# 2026-02-06 21:03:14,963 - INFO - Valid improvement (0.010338 > 0.001). Model saved.
# Epoch 4/50: 100%|██████████| 627/627 [00:02<00:00, 243.44it/s]
# 2026-02-06 21:03:17,544 - INFO - [Epoch 4] Average Loss: 0.525448
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 417.81it/s]
# 2026-02-06 21:03:18,086 - INFO - [Epoch 4] Validation AUC: 0.743783, ACC: 0.715843
# 2026-02-06 21:03:18,086 - INFO - save parameters to paras_EADCD\model_random_random_fold_3.snapshot
# 2026-02-06 21:03:18,086 - INFO - Valid improvement (0.009256 > 0.001). Model saved.
# Epoch 5/50: 100%|██████████| 627/627 [00:02<00:00, 234.22it/s]
# 2026-02-06 21:03:20,763 - INFO - [Epoch 5] Average Loss: 0.511622
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 426.97it/s]
# 2026-02-06 21:03:21,302 - INFO - [Epoch 5] Validation AUC: 0.748521, ACC: 0.719432
# 2026-02-06 21:03:21,305 - INFO - save parameters to paras_EADCD\model_random_random_fold_3.snapshot
# 2026-02-06 21:03:21,306 - INFO - Valid improvement (0.004739 > 0.001). Model saved.
# Epoch 6/50: 100%|██████████| 627/627 [00:02<00:00, 243.75it/s]
# 2026-02-06 21:03:23,879 - INFO - [Epoch 6] Average Loss: 0.498189
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 418.05it/s]
# 2026-02-06 21:03:24,419 - INFO - [Epoch 6] Validation AUC: 0.752463, ACC: 0.721862
# 2026-02-06 21:03:24,423 - INFO - save parameters to paras_EADCD\model_random_random_fold_3.snapshot
# 2026-02-06 21:03:24,423 - INFO - Valid improvement (0.003942 > 0.001). Model saved.
# Epoch 7/50: 100%|██████████| 627/627 [00:02<00:00, 240.82it/s]
# 2026-02-06 21:03:27,028 - INFO - [Epoch 7] Average Loss: 0.484532
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 418.41it/s]
# 2026-02-06 21:03:27,572 - INFO - [Epoch 7] Validation AUC: 0.757934, ACC: 0.726292
# 2026-02-06 21:03:27,576 - INFO - save parameters to paras_EADCD\model_random_random_fold_3.snapshot
# 2026-02-06 21:03:27,577 - INFO - Valid improvement (0.005471 > 0.001). Model saved.
# Epoch 8/50: 100%|██████████| 627/627 [00:02<00:00, 227.35it/s]
# 2026-02-06 21:03:30,336 - INFO - [Epoch 8] Average Loss: 0.469414
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 417.84it/s]
# 2026-02-06 21:03:30,878 - INFO - [Epoch 8] Validation AUC: 0.760895, ACC: 0.728049
# 2026-02-06 21:03:30,887 - INFO - save parameters to paras_EADCD\model_random_random_fold_3.snapshot
# 2026-02-06 21:03:30,888 - INFO - Valid improvement (0.002961 > 0.001). Model saved.
# Epoch 9/50: 100%|██████████| 627/627 [00:02<00:00, 225.46it/s]
# 2026-02-06 21:03:33,671 - INFO - [Epoch 9] Average Loss: 0.452503
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 398.72it/s]
# 2026-02-06 21:03:34,242 - INFO - [Epoch 9] Validation AUC: 0.764501, ACC: 0.730274
# 2026-02-06 21:03:34,246 - INFO - save parameters to paras_EADCD\model_random_random_fold_3.snapshot
# 2026-02-06 21:03:34,246 - INFO - Valid improvement (0.003606 > 0.001). Model saved.
# Epoch 10/50: 100%|██████████| 627/627 [00:02<00:00, 233.88it/s]
# 2026-02-06 21:03:36,935 - INFO - [Epoch 10] Average Loss: 0.433463
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 409.50it/s]
# 2026-02-06 21:03:37,490 - INFO - [Epoch 10] Validation AUC: 0.768086, ACC: 0.733358
# 2026-02-06 21:03:37,494 - INFO - save parameters to paras_EADCD\model_random_random_fold_3.snapshot
# 2026-02-06 21:03:37,495 - INFO - Valid improvement (0.003585 > 0.001). Model saved.
# Epoch 11/50: 100%|██████████| 627/627 [00:02<00:00, 226.58it/s]
# 2026-02-06 21:03:40,263 - INFO - [Epoch 11] Average Loss: 0.412742
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 423.35it/s]
# 2026-02-06 21:03:40,800 - INFO - [Epoch 11] Validation AUC: 0.771045, ACC: 0.735228
# 2026-02-06 21:03:40,803 - INFO - save parameters to paras_EADCD\model_random_random_fold_3.snapshot
# 2026-02-06 21:03:40,803 - INFO - Valid improvement (0.002959 > 0.001). Model saved.
# Epoch 12/50: 100%|██████████| 627/627 [00:02<00:00, 240.68it/s]
# 2026-02-06 21:03:43,408 - INFO - [Epoch 12] Average Loss: 0.390734
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 422.53it/s]
# 2026-02-06 21:03:43,946 - INFO - [Epoch 12] Validation AUC: 0.774808, ACC: 0.737340
# 2026-02-06 21:03:43,949 - INFO - save parameters to paras_EADCD\model_random_random_fold_3.snapshot
# 2026-02-06 21:03:43,949 - INFO - Valid improvement (0.003763 > 0.001). Model saved.
# Epoch 13/50: 100%|██████████| 627/627 [00:02<00:00, 244.33it/s]
# 2026-02-06 21:03:46,518 - INFO - [Epoch 13] Average Loss: 0.367960
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 412.38it/s]
# 2026-02-06 21:03:47,068 - INFO - [Epoch 13] Validation AUC: 0.776304, ACC: 0.737658
# 2026-02-06 21:03:47,069 - INFO - save parameters to paras_EADCD\model_random_random_fold_3.snapshot
# 2026-02-06 21:03:47,069 - INFO - Valid improvement (0.001496 > 0.001). Model saved.
# Epoch 14/50: 100%|██████████| 627/627 [00:02<00:00, 235.27it/s]
# 2026-02-06 21:03:49,735 - INFO - [Epoch 14] Average Loss: 0.344958
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 424.41it/s]
# 2026-02-06 21:03:50,272 - INFO - [Epoch 14] Validation AUC: 0.777165, ACC: 0.737658
# 2026-02-06 21:03:50,272 - INFO - Early stopping triggered at epoch 14.
# 2026-02-06 21:03:50,274 - INFO - --- random_fold_3 Best epoch: 13 ---
# 2026-02-06 21:03:50,274 - INFO - Loading best model from random_fold_3 for final test evaluation...
# 2026-02-06 21:03:50,298 - INFO - load parameters from paras_EADCD\model_random_random_fold_3.snapshot
# Evaluating: 100%|██████████| 209/209 [00:00<00:00, 426.81it/s]
# 2026-02-06 21:03:50,836 - INFO - random_fold_3 Test Performance --- AUC: 0.777574, ACC: 0.738231, RMSE: 0.420015, F1: 0.813695
# 2026-02-06 21:03:50,841 - INFO -
# ==================== Starting Random Split Fold 4/5 ====================
# 2026-02-06 21:03:51,513 - INFO - random_fold_4: Train=160809, Val=53603, Test=53011
# 2026-02-06 21:03:55,396 - INFO - Training MIRT (dim=16)... (lr=0.002)
# Epoch 1/50: 100%|██████████| 629/629 [00:02<00:00, 228.81it/s]
# 2026-02-06 21:03:58,149 - INFO - [Epoch 1] Average Loss: 0.604221
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 418.70it/s]
# 2026-02-06 21:03:58,695 - INFO - [Epoch 1] Validation AUC: 0.703608, ACC: 0.704308
# 2026-02-06 21:03:58,695 - INFO - save parameters to paras_EADCD\model_random_random_fold_4.snapshot
# 2026-02-06 21:03:58,695 - INFO - Valid improvement (0.703608 > 0.001). Model saved.
# Epoch 2/50: 100%|██████████| 629/629 [00:02<00:00, 256.79it/s]
# 2026-02-06 21:04:01,146 - INFO - [Epoch 2] Average Loss: 0.560754
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 332.37it/s]
# 2026-02-06 21:04:01,821 - INFO - [Epoch 2] Validation AUC: 0.722927, ACC: 0.707386
# 2026-02-06 21:04:01,823 - INFO - save parameters to paras_EADCD\model_random_random_fold_4.snapshot
# 2026-02-06 21:04:01,824 - INFO - Valid improvement (0.019319 > 0.001). Model saved.
# Epoch 3/50: 100%|██████████| 629/629 [00:02<00:00, 230.68it/s]
# 2026-02-06 21:04:04,552 - INFO - [Epoch 3] Average Loss: 0.541737
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 349.82it/s]
# 2026-02-06 21:04:05,186 - INFO - [Epoch 3] Validation AUC: 0.734686, ACC: 0.712889
# 2026-02-06 21:04:05,197 - INFO - save parameters to paras_EADCD\model_random_random_fold_4.snapshot
# 2026-02-06 21:04:05,197 - INFO - Valid improvement (0.011759 > 0.001). Model saved.
# Epoch 4/50: 100%|██████████| 629/629 [00:02<00:00, 229.09it/s]
# 2026-02-06 21:04:07,944 - INFO - [Epoch 4] Average Loss: 0.525947
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 324.22it/s]
# 2026-02-06 21:04:08,641 - INFO - [Epoch 4] Validation AUC: 0.742688, ACC: 0.715128
# 2026-02-06 21:04:08,644 - INFO - save parameters to paras_EADCD\model_random_random_fold_4.snapshot
# 2026-02-06 21:04:08,645 - INFO - Valid improvement (0.008002 > 0.001). Model saved.
# Epoch 5/50: 100%|██████████| 629/629 [00:03<00:00, 190.24it/s]
# 2026-02-06 21:04:11,952 - INFO - [Epoch 5] Average Loss: 0.511815
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 318.42it/s]
# 2026-02-06 21:04:12,668 - INFO - [Epoch 5] Validation AUC: 0.749202, ACC: 0.720538
# 2026-02-06 21:04:12,671 - INFO - save parameters to paras_EADCD\model_random_random_fold_4.snapshot
# 2026-02-06 21:04:12,671 - INFO - Valid improvement (0.006514 > 0.001). Model saved.
# Epoch 6/50: 100%|██████████| 629/629 [00:02<00:00, 236.76it/s]
# 2026-02-06 21:04:15,329 - INFO - [Epoch 6] Average Loss: 0.498516
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 414.48it/s]
# 2026-02-06 21:04:15,879 - INFO - [Epoch 6] Validation AUC: 0.754105, ACC: 0.724306
# 2026-02-06 21:04:15,885 - INFO - save parameters to paras_EADCD\model_random_random_fold_4.snapshot
# 2026-02-06 21:04:15,886 - INFO - Valid improvement (0.004903 > 0.001). Model saved.
# Epoch 7/50: 100%|██████████| 629/629 [00:02<00:00, 240.30it/s]
# 2026-02-06 21:04:18,506 - INFO - [Epoch 7] Average Loss: 0.484555
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 357.14it/s]
# 2026-02-06 21:04:19,140 - INFO - [Epoch 7] Validation AUC: 0.757200, ACC: 0.726862
# 2026-02-06 21:04:19,142 - INFO - save parameters to paras_EADCD\model_random_random_fold_4.snapshot
# 2026-02-06 21:04:19,142 - INFO - Valid improvement (0.003095 > 0.001). Model saved.
# Epoch 8/50: 100%|██████████| 629/629 [00:02<00:00, 240.53it/s]
# 2026-02-06 21:04:21,761 - INFO - [Epoch 8] Average Loss: 0.469297
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 419.36it/s]
# 2026-02-06 21:04:22,302 - INFO - [Epoch 8] Validation AUC: 0.761584, ACC: 0.729101
# 2026-02-06 21:04:22,302 - INFO - save parameters to paras_EADCD\model_random_random_fold_4.snapshot
# 2026-02-06 21:04:22,302 - INFO - Valid improvement (0.004384 > 0.001). Model saved.
# Epoch 9/50: 100%|██████████| 629/629 [00:02<00:00, 245.59it/s]
# 2026-02-06 21:04:24,874 - INFO - [Epoch 9] Average Loss: 0.451678
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 387.66it/s]
# 2026-02-06 21:04:25,452 - INFO - [Epoch 9] Validation AUC: 0.765683, ACC: 0.732478
# 2026-02-06 21:04:25,462 - INFO - save parameters to paras_EADCD\model_random_random_fold_4.snapshot
# 2026-02-06 21:04:25,462 - INFO - Valid improvement (0.004098 > 0.001). Model saved.
# Epoch 10/50: 100%|██████████| 629/629 [00:02<00:00, 245.97it/s]
# 2026-02-06 21:04:28,019 - INFO - [Epoch 10] Average Loss: 0.432368
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 411.46it/s]
# 2026-02-06 21:04:28,572 - INFO - [Epoch 10] Validation AUC: 0.769889, ACC: 0.735500
# 2026-02-06 21:04:28,575 - INFO - save parameters to paras_EADCD\model_random_random_fold_4.snapshot
# 2026-02-06 21:04:28,575 - INFO - Valid improvement (0.004206 > 0.001). Model saved.
# Epoch 11/50: 100%|██████████| 629/629 [00:02<00:00, 243.67it/s]
# 2026-02-06 21:04:31,159 - INFO - [Epoch 11] Average Loss: 0.411182
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 374.44it/s]
# 2026-02-06 21:04:31,765 - INFO - [Epoch 11] Validation AUC: 0.772651, ACC: 0.736451
# 2026-02-06 21:04:31,767 - INFO - save parameters to paras_EADCD\model_random_random_fold_4.snapshot
# 2026-02-06 21:04:31,768 - INFO - Valid improvement (0.002763 > 0.001). Model saved.
# Epoch 12/50: 100%|██████████| 629/629 [00:02<00:00, 243.69it/s]
# 2026-02-06 21:04:34,349 - INFO - [Epoch 12] Average Loss: 0.388564
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 360.67it/s]
# 2026-02-06 21:04:34,977 - INFO - [Epoch 12] Validation AUC: 0.775408, ACC: 0.739100
# 2026-02-06 21:04:34,981 - INFO - save parameters to paras_EADCD\model_random_random_fold_4.snapshot
# 2026-02-06 21:04:34,981 - INFO - Valid improvement (0.002756 > 0.001). Model saved.
# Epoch 13/50: 100%|██████████| 629/629 [00:02<00:00, 245.49it/s]
# 2026-02-06 21:04:37,545 - INFO - [Epoch 13] Average Loss: 0.365491
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 346.42it/s]
# 2026-02-06 21:04:38,202 - INFO - [Epoch 13] Validation AUC: 0.777784, ACC: 0.739996
# 2026-02-06 21:04:38,205 - INFO - save parameters to paras_EADCD\model_random_random_fold_4.snapshot
# 2026-02-06 21:04:38,205 - INFO - Valid improvement (0.002377 > 0.001). Model saved.
# Epoch 14/50: 100%|██████████| 629/629 [00:02<00:00, 234.90it/s]
# 2026-02-06 21:04:40,885 - INFO - [Epoch 14] Average Loss: 0.342277
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 338.06it/s]
# 2026-02-06 21:04:41,549 - INFO - [Epoch 14] Validation AUC: 0.778859, ACC: 0.740313
# 2026-02-06 21:04:41,552 - INFO - save parameters to paras_EADCD\model_random_random_fold_4.snapshot
# 2026-02-06 21:04:41,552 - INFO - Valid improvement (0.001074 > 0.001). Model saved.
# Epoch 15/50: 100%|██████████| 629/629 [00:02<00:00, 235.03it/s]
# 2026-02-06 21:04:44,228 - INFO - [Epoch 15] Average Loss: 0.319420
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 406.23it/s]
# 2026-02-06 21:04:44,787 - INFO - [Epoch 15] Validation AUC: 0.779609, ACC: 0.741320
# 2026-02-06 21:04:44,787 - INFO - Early stopping triggered at epoch 15.
# 2026-02-06 21:04:44,787 - INFO - --- random_fold_4 Best epoch: 14 ---
# 2026-02-06 21:04:44,787 - INFO - Loading best model from random_fold_4 for final test evaluation...
# 2026-02-06 21:04:44,821 - INFO - load parameters from paras_EADCD\model_random_random_fold_4.snapshot
# Evaluating: 100%|██████████| 208/208 [00:00<00:00, 418.25it/s]
# 2026-02-06 21:04:45,371 - INFO - random_fold_4 Test Performance --- AUC: 0.775731, ACC: 0.738318, RMSE: 0.420358, F1: 0.813729
# 2026-02-06 21:04:45,376 - INFO -
# ==================== Starting Random Split Fold 5/5 ====================
# 2026-02-06 21:04:46,044 - INFO - random_fold_5: Train=161155, Val=53719, Test=52549
# 2026-02-06 21:04:50,045 - INFO - Training MIRT (dim=16)... (lr=0.002)
# Epoch 1/50: 100%|██████████| 630/630 [00:02<00:00, 230.46it/s]
# 2026-02-06 21:04:52,785 - INFO - [Epoch 1] Average Loss: 0.604618
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 393.74it/s]
# 2026-02-06 21:04:53,368 - INFO - [Epoch 1] Validation AUC: 0.704000, ACC: 0.700181
# 2026-02-06 21:04:53,371 - INFO - save parameters to paras_EADCD\model_random_random_fold_5.snapshot
# 2026-02-06 21:04:53,372 - INFO - Valid improvement (0.704000 > 0.001). Model saved.
# Epoch 2/50: 100%|██████████| 630/630 [00:02<00:00, 259.34it/s]
# 2026-02-06 21:04:55,802 - INFO - [Epoch 2] Average Loss: 0.560960
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 357.48it/s]
# 2026-02-06 21:04:56,435 - INFO - [Epoch 2] Validation AUC: 0.722072, ACC: 0.705914
# 2026-02-06 21:04:56,441 - INFO - save parameters to paras_EADCD\model_random_random_fold_5.snapshot
# 2026-02-06 21:04:56,445 - INFO - Valid improvement (0.018072 > 0.001). Model saved.
# Epoch 3/50: 100%|██████████| 630/630 [00:02<00:00, 248.40it/s]
# 2026-02-06 21:04:58,982 - INFO - [Epoch 3] Average Loss: 0.541781
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 362.68it/s]
# 2026-02-06 21:04:59,609 - INFO - [Epoch 3] Validation AUC: 0.733451, ACC: 0.709600
# 2026-02-06 21:04:59,612 - INFO - save parameters to paras_EADCD\model_random_random_fold_5.snapshot
# 2026-02-06 21:04:59,612 - INFO - Valid improvement (0.011379 > 0.001). Model saved.
# Epoch 4/50: 100%|██████████| 630/630 [00:02<00:00, 233.39it/s]
# 2026-02-06 21:05:02,312 - INFO - [Epoch 4] Average Loss: 0.526007
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 352.42it/s]
# 2026-02-06 21:05:02,971 - INFO - [Epoch 4] Validation AUC: 0.744223, ACC: 0.715147
# 2026-02-06 21:05:02,976 - INFO - save parameters to paras_EADCD\model_random_random_fold_5.snapshot
# 2026-02-06 21:05:02,977 - INFO - Valid improvement (0.010772 > 0.001). Model saved.
# Epoch 5/50: 100%|██████████| 630/630 [00:02<00:00, 228.57it/s]
# 2026-02-06 21:05:05,746 - INFO - [Epoch 5] Average Loss: 0.512186
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 406.04it/s]
# 2026-02-06 21:05:06,302 - INFO - [Epoch 5] Validation AUC: 0.749933, ACC: 0.720304
# 2026-02-06 21:05:06,302 - INFO - save parameters to paras_EADCD\model_random_random_fold_5.snapshot
# 2026-02-06 21:05:06,302 - INFO - Valid improvement (0.005710 > 0.001). Model saved.
# Epoch 6/50: 100%|██████████| 630/630 [00:02<00:00, 235.46it/s]
# 2026-02-06 21:05:08,978 - INFO - [Epoch 6] Average Loss: 0.498517
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 406.36it/s]
# 2026-02-06 21:05:09,537 - INFO - [Epoch 6] Validation AUC: 0.754557, ACC: 0.722761
# 2026-02-06 21:05:09,542 - INFO - save parameters to paras_EADCD\model_random_random_fold_5.snapshot
# 2026-02-06 21:05:09,542 - INFO - Valid improvement (0.004624 > 0.001). Model saved.
# Epoch 7/50: 100%|██████████| 630/630 [00:02<00:00, 240.03it/s]
# 2026-02-06 21:05:12,170 - INFO - [Epoch 7] Average Loss: 0.484315
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 422.43it/s]
# 2026-02-06 21:05:12,712 - INFO - [Epoch 7] Validation AUC: 0.759616, ACC: 0.726428
# 2026-02-06 21:05:12,719 - INFO - save parameters to paras_EADCD\model_random_random_fold_5.snapshot
# 2026-02-06 21:05:12,720 - INFO - Valid improvement (0.005060 > 0.001). Model saved.
# Epoch 8/50: 100%|██████████| 630/630 [00:02<00:00, 240.16it/s]
# 2026-02-06 21:05:15,345 - INFO - [Epoch 8] Average Loss: 0.468740
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 419.55it/s]
# 2026-02-06 21:05:15,893 - INFO - [Epoch 8] Validation AUC: 0.763544, ACC: 0.729723
# 2026-02-06 21:05:15,896 - INFO - save parameters to paras_EADCD\model_random_random_fold_5.snapshot
# 2026-02-06 21:05:15,897 - INFO - Valid improvement (0.003927 > 0.001). Model saved.
# Epoch 9/50: 100%|██████████| 630/630 [00:02<00:00, 239.82it/s]
# 2026-02-06 21:05:18,525 - INFO - [Epoch 9] Average Loss: 0.450987
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 346.56it/s]
# 2026-02-06 21:05:19,177 - INFO - [Epoch 9] Validation AUC: 0.768018, ACC: 0.733130
# 2026-02-06 21:05:19,180 - INFO - save parameters to paras_EADCD\model_random_random_fold_5.snapshot
# 2026-02-06 21:05:19,181 - INFO - Valid improvement (0.004474 > 0.001). Model saved.
# Epoch 10/50: 100%|██████████| 630/630 [00:02<00:00, 242.62it/s]
# 2026-02-06 21:05:21,779 - INFO - [Epoch 10] Average Loss: 0.431337
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 412.09it/s]
# 2026-02-06 21:05:22,331 - INFO - [Epoch 10] Validation AUC: 0.772001, ACC: 0.735457
# 2026-02-06 21:05:22,334 - INFO - save parameters to paras_EADCD\model_random_random_fold_5.snapshot
# 2026-02-06 21:05:22,334 - INFO - Valid improvement (0.003983 > 0.001). Model saved.
# Epoch 11/50: 100%|██████████| 630/630 [00:02<00:00, 237.73it/s]
# 2026-02-06 21:05:24,985 - INFO - [Epoch 11] Average Loss: 0.409903
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 348.25it/s]
# 2026-02-06 21:05:25,630 - INFO - [Epoch 11] Validation AUC: 0.775297, ACC: 0.737914
# 2026-02-06 21:05:25,633 - INFO - save parameters to paras_EADCD\model_random_random_fold_5.snapshot
# 2026-02-06 21:05:25,634 - INFO - Valid improvement (0.003296 > 0.001). Model saved.
# Epoch 12/50: 100%|██████████| 630/630 [00:02<00:00, 250.78it/s]
# 2026-02-06 21:05:28,147 - INFO - [Epoch 12] Average Loss: 0.387593
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 339.23it/s]
# 2026-02-06 21:05:28,812 - INFO - [Epoch 12] Validation AUC: 0.778221, ACC: 0.738845
# 2026-02-06 21:05:28,812 - INFO - save parameters to paras_EADCD\model_random_random_fold_5.snapshot
# 2026-02-06 21:05:28,812 - INFO - Valid improvement (0.002924 > 0.001). Model saved.
# Epoch 13/50: 100%|██████████| 630/630 [00:02<00:00, 243.86it/s]
# 2026-02-06 21:05:31,402 - INFO - [Epoch 13] Average Loss: 0.364577
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 352.71it/s]
# 2026-02-06 21:05:32,035 - INFO - [Epoch 13] Validation AUC: 0.779758, ACC: 0.740390
# 2026-02-06 21:05:32,035 - INFO - save parameters to paras_EADCD\model_random_random_fold_5.snapshot
# 2026-02-06 21:05:32,035 - INFO - Valid improvement (0.001537 > 0.001). Model saved.
# Epoch 14/50: 100%|██████████| 630/630 [00:02<00:00, 230.42it/s]
# 2026-02-06 21:05:34,769 - INFO - [Epoch 14] Average Loss: 0.341545
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 407.56it/s]
# 2026-02-06 21:05:35,329 - INFO - [Epoch 14] Validation AUC: 0.780761, ACC: 0.741469
# 2026-02-06 21:05:35,335 - INFO - save parameters to paras_EADCD\model_random_random_fold_5.snapshot
# 2026-02-06 21:05:35,335 - INFO - Valid improvement (0.001003 > 0.001). Model saved.
# Epoch 15/50: 100%|██████████| 630/630 [00:02<00:00, 246.16it/s]
# 2026-02-06 21:05:37,898 - INFO - [Epoch 15] Average Loss: 0.319043
# Evaluating: 100%|██████████| 210/210 [00:00<00:00, 425.81it/s]
# 2026-02-06 21:05:38,435 - INFO - [Epoch 15] Validation AUC: 0.781680, ACC: 0.741786
# 2026-02-06 21:05:38,435 - INFO - Early stopping triggered at epoch 15.
# 2026-02-06 21:05:38,435 - INFO - --- random_fold_5 Best epoch: 14 ---
# 2026-02-06 21:05:38,435 - INFO - Loading best model from random_fold_5 for final test evaluation...
# 2026-02-06 21:05:38,463 - INFO - load parameters from paras_EADCD\model_random_random_fold_5.snapshot
# Evaluating: 100%|██████████| 206/206 [00:00<00:00, 401.59it/s]
# 2026-02-06 21:05:39,020 - INFO - random_fold_5 Test Performance --- AUC: 0.778612, ACC: 0.741841, RMSE: 0.419086, F1: 0.815739
# ==================== 5-Fold Cross-Validation Summary (Random Split) ====================
# Parameters: train_fraction=1.0, epochs=50, seed=123
# Average AUC:  0.777695 ± 0.001291
# Average ACC:  0.739653 ± 0.001500
# Average RMSE: 0.419807 ± 0.001114
# Average F1:   0.814509 ± 0.001197

# %% [markdown]
# ### junyi

# %% [markdown]
# **100% train**

# %%
runner = ADCD_Runner(
    model_class=MIRT,
    input_dir='../../Data/data/J123',
    split_type='random',
    train_fraction=1.0,
    **hyperparams
)
runner.run()
# Out:
# 2026-02-06 21:32:56,732 - INFO - Using device: cuda
# 2026-02-06 21:32:56,761 - INFO - Loading metadata and p2k mapping...
# 2026-02-06 21:32:56,786 - INFO - 10000 users, 675 problems, 510 skills.
# 2026-02-06 21:32:56,831 - INFO - Pre-building global problem Q-matrix...
# 2026-02-06 21:32:56,882 - INFO -
# ==================== Starting Random Split Fold 1/5 ====================
# 2026-02-06 21:33:00,907 - INFO - random_fold_1: Train=242796, Val=80932, Test=85890
# 2026-02-06 21:33:26,504 - INFO - Training MIRT (dim=16)... (lr=0.002)
# Epoch 1/50: 100%|██████████| 949/949 [00:05<00:00, 181.52it/s]
# 2026-02-06 21:33:31,753 - INFO - [Epoch 1] Average Loss: 0.568403
# Evaluating: 100%|██████████| 317/317 [00:00<00:00, 379.70it/s]
# 2026-02-06 21:33:32,662 - INFO - [Epoch 1] Validation AUC: 0.782135, ACC: 0.739127
# 2026-02-06 21:33:32,674 - INFO - save parameters to paras_EADCD\model_random_random_fold_1.snapshot
# 2026-02-06 21:33:32,674 - INFO - Valid improvement (0.782135 > 0.001). Model saved.
# Epoch 2/50: 100%|██████████| 949/949 [00:05<00:00, 169.94it/s]
# 2026-02-06 21:33:38,261 - INFO - [Epoch 2] Average Loss: 0.495502
# Evaluating: 100%|██████████| 317/317 [00:00<00:00, 326.85it/s]
# 2026-02-06 21:33:39,293 - INFO - [Epoch 2] Validation AUC: 0.795789, ACC: 0.754732
# 2026-02-06 21:33:39,302 - INFO - save parameters to paras_EADCD\model_random_random_fold_1.snapshot
# 2026-02-06 21:33:39,302 - INFO - Valid improvement (0.013654 > 0.001). Model saved.
# Epoch 3/50: 100%|██████████| 949/949 [00:04<00:00, 192.44it/s]
# 2026-02-06 21:33:44,234 - INFO - [Epoch 3] Average Loss: 0.478630
# Evaluating: 100%|██████████| 317/317 [00:00<00:00, 352.33it/s]
# 2026-02-06 21:33:45,210 - INFO - [Epoch 3] Validation AUC: 0.800717, ACC: 0.760713
# 2026-02-06 21:33:45,213 - INFO - save parameters to paras_EADCD\model_random_random_fold_1.snapshot
# 2026-02-06 21:33:45,213 - INFO - Valid improvement (0.004928 > 0.001). Model saved.
# Epoch 4/50: 100%|██████████| 949/949 [00:05<00:00, 185.54it/s]
# 2026-02-06 21:33:50,327 - INFO - [Epoch 4] Average Loss: 0.469429
# Evaluating: 100%|██████████| 317/317 [00:00<00:00, 322.78it/s]
# 2026-02-06 21:33:51,379 - INFO - [Epoch 4] Validation AUC: 0.803590, ACC: 0.763122
# 2026-02-06 21:33:51,379 - INFO - save parameters to paras_EADCD\model_random_random_fold_1.snapshot
# 2026-02-06 21:33:51,379 - INFO - Valid improvement (0.002873 > 0.001). Model saved.
# Epoch 5/50: 100%|██████████| 949/949 [00:05<00:00, 179.31it/s]
# 2026-02-06 21:33:56,673 - INFO - [Epoch 5] Average Loss: 0.463198
# Evaluating: 100%|██████████| 317/317 [00:00<00:00, 347.17it/s]
# 2026-02-06 21:33:57,659 - INFO - [Epoch 5] Validation AUC: 0.805543, ACC: 0.765717
# 2026-02-06 21:33:57,662 - INFO - save parameters to paras_EADCD\model_random_random_fold_1.snapshot
# 2026-02-06 21:33:57,663 - INFO - Valid improvement (0.001953 > 0.001). Model saved.
# Epoch 6/50: 100%|██████████| 949/949 [00:05<00:00, 178.61it/s]
# 2026-02-06 21:34:02,978 - INFO - [Epoch 6] Average Loss: 0.458012
# Evaluating: 100%|██████████| 317/317 [00:01<00:00, 307.50it/s]
# 2026-02-06 21:34:04,076 - INFO - [Epoch 6] Validation AUC: 0.806108, ACC: 0.766644
# 2026-02-06 21:34:04,076 - INFO - Early stopping triggered at epoch 6.
# 2026-02-06 21:34:04,085 - INFO - --- random_fold_1 Best epoch: 5 ---
# 2026-02-06 21:34:04,085 - INFO - Loading best model from random_fold_1 for final test evaluation...
# 2026-02-06 21:34:04,096 - INFO - load parameters from paras_EADCD\model_random_random_fold_1.snapshot
# Evaluating: 100%|██████████| 336/336 [00:01<00:00, 331.91it/s]
# 2026-02-06 21:34:05,185 - INFO - random_fold_1 Test Performance --- AUC: 0.807929, ACC: 0.765735, RMSE: 0.400631, F1: 0.835113
# 2026-02-06 21:34:05,185 - INFO -
# ==================== Starting Random Split Fold 2/5 ====================
# 2026-02-06 21:34:09,802 - INFO - random_fold_2: Train=244371, Val=81458, Test=83789
# 2026-02-06 21:34:34,676 - INFO - Training MIRT (dim=16)... (lr=0.002)
# Epoch 1/50: 100%|██████████| 955/955 [00:05<00:00, 169.72it/s]
# 2026-02-06 21:34:40,338 - INFO - [Epoch 1] Average Loss: 0.569375
# Evaluating: 100%|██████████| 319/319 [00:01<00:00, 298.09it/s]
# 2026-02-06 21:34:41,490 - INFO - [Epoch 1] Validation AUC: 0.783142, ACC: 0.741695
# 2026-02-06 21:34:41,504 - INFO - save parameters to paras_EADCD\model_random_random_fold_2.snapshot
# 2026-02-06 21:34:41,505 - INFO - Valid improvement (0.783142 > 0.001). Model saved.
# Epoch 2/50: 100%|██████████| 955/955 [00:04<00:00, 192.35it/s]
# 2026-02-06 21:34:46,474 - INFO - [Epoch 2] Average Loss: 0.496451
# Evaluating: 100%|██████████| 319/319 [00:01<00:00, 296.45it/s]
# 2026-02-06 21:34:47,632 - INFO - [Epoch 2] Validation AUC: 0.795867, ACC: 0.755543
# 2026-02-06 21:34:47,635 - INFO - save parameters to paras_EADCD\model_random_random_fold_2.snapshot
# 2026-02-06 21:34:47,636 - INFO - Valid improvement (0.012725 > 0.001). Model saved.
# Epoch 3/50: 100%|██████████| 955/955 [00:05<00:00, 161.33it/s]
# 2026-02-06 21:34:53,561 - INFO - [Epoch 3] Average Loss: 0.479201
# Evaluating: 100%|██████████| 319/319 [00:01<00:00, 276.57it/s]
# 2026-02-06 21:34:54,792 - INFO - [Epoch 3] Validation AUC: 0.801081, ACC: 0.760392
# 2026-02-06 21:34:54,792 - INFO - save parameters to paras_EADCD\model_random_random_fold_2.snapshot
# 2026-02-06 21:34:54,792 - INFO - Valid improvement (0.005214 > 0.001). Model saved.
# Epoch 4/50: 100%|██████████| 955/955 [00:04<00:00, 218.81it/s]
# 2026-02-06 21:34:59,159 - INFO - [Epoch 4] Average Loss: 0.470225
# Evaluating: 100%|██████████| 319/319 [00:01<00:00, 274.99it/s]
# 2026-02-06 21:35:00,394 - INFO - [Epoch 4] Validation AUC: 0.804059, ACC: 0.764112
# 2026-02-06 21:35:00,399 - INFO - save parameters to paras_EADCD\model_random_random_fold_2.snapshot
# 2026-02-06 21:35:00,399 - INFO - Valid improvement (0.002978 > 0.001). Model saved.
# Epoch 5/50: 100%|██████████| 955/955 [00:04<00:00, 207.92it/s]
# 2026-02-06 21:35:04,992 - INFO - [Epoch 5] Average Loss: 0.463838
# Evaluating: 100%|██████████| 319/319 [00:01<00:00, 261.61it/s]
# 2026-02-06 21:35:06,286 - INFO - [Epoch 5] Validation AUC: 0.806172, ACC: 0.765769
# 2026-02-06 21:35:06,289 - INFO - save parameters to paras_EADCD\model_random_random_fold_2.snapshot
# 2026-02-06 21:35:06,291 - INFO - Valid improvement (0.002113 > 0.001). Model saved.
# Epoch 6/50: 100%|██████████| 955/955 [00:04<00:00, 213.39it/s]
# 2026-02-06 21:35:10,770 - INFO - [Epoch 6] Average Loss: 0.458350
# Evaluating: 100%|██████████| 319/319 [00:01<00:00, 280.26it/s]
# 2026-02-06 21:35:11,986 - INFO - [Epoch 6] Validation AUC: 0.807263, ACC: 0.766861
# 2026-02-06 21:35:11,989 - INFO - save parameters to paras_EADCD\model_random_random_fold_2.snapshot
# 2026-02-06 21:35:11,990 - INFO - Valid improvement (0.001092 > 0.001). Model saved.
# Epoch 7/50: 100%|██████████| 955/955 [00:04<00:00, 197.70it/s]
# 2026-02-06 21:35:16,824 - INFO - [Epoch 7] Average Loss: 0.451762
# Evaluating: 100%|██████████| 319/319 [00:01<00:00, 279.88it/s]
# 2026-02-06 21:35:18,045 - INFO - [Epoch 7] Validation AUC: 0.807222, ACC: 0.766162
# 2026-02-06 21:35:18,046 - INFO - Early stopping triggered at epoch 7.
# 2026-02-06 21:35:18,047 - INFO - --- random_fold_2 Best epoch: 6 ---
# 2026-02-06 21:35:18,048 - INFO - Loading best model from random_fold_2 for final test evaluation...
# 2026-02-06 21:35:18,072 - INFO - load parameters from paras_EADCD\model_random_random_fold_2.snapshot
# Evaluating: 100%|██████████| 328/328 [00:01<00:00, 225.68it/s]
# 2026-02-06 21:35:19,608 - INFO - random_fold_2 Test Performance --- AUC: 0.809600, ACC: 0.769731, RMSE: 0.398314, F1: 0.838452
# 2026-02-06 21:35:19,609 - INFO -
# ==================== Starting Random Split Fold 3/5 ====================
# 2026-02-06 21:35:24,709 - INFO - random_fold_3: Train=245846, Val=81949, Test=81823
# 2026-02-06 21:35:50,380 - INFO - Training MIRT (dim=16)... (lr=0.002)
# Epoch 1/50: 100%|██████████| 961/961 [00:04<00:00, 204.86it/s]
# 2026-02-06 21:35:55,076 - INFO - [Epoch 1] Average Loss: 0.569308
# Evaluating: 100%|██████████| 321/321 [00:01<00:00, 266.84it/s]
# 2026-02-06 21:35:56,370 - INFO - [Epoch 1] Validation AUC: 0.783993, ACC: 0.742291
# 2026-02-06 21:35:56,374 - INFO - save parameters to paras_EADCD\model_random_random_fold_3.snapshot
# 2026-02-06 21:35:56,375 - INFO - Valid improvement (0.783993 > 0.001). Model saved.
# Epoch 2/50: 100%|██████████| 961/961 [00:04<00:00, 224.29it/s]
# 2026-02-06 21:36:00,663 - INFO - [Epoch 2] Average Loss: 0.496678
# Evaluating: 100%|██████████| 321/321 [00:01<00:00, 286.57it/s]
# 2026-02-06 21:36:01,857 - INFO - [Epoch 2] Validation AUC: 0.798144, ACC: 0.757325
# 2026-02-06 21:36:01,860 - INFO - save parameters to paras_EADCD\model_random_random_fold_3.snapshot
# 2026-02-06 21:36:01,861 - INFO - Valid improvement (0.014151 > 0.001). Model saved.
# Epoch 3/50: 100%|██████████| 961/961 [00:04<00:00, 204.16it/s]
# 2026-02-06 21:36:06,571 - INFO - [Epoch 3] Average Loss: 0.479636
# Evaluating: 100%|██████████| 321/321 [00:01<00:00, 300.44it/s]
# 2026-02-06 21:36:07,729 - INFO - [Epoch 3] Validation AUC: 0.803711, ACC: 0.762535
# 2026-02-06 21:36:07,733 - INFO - save parameters to paras_EADCD\model_random_random_fold_3.snapshot
# 2026-02-06 21:36:07,735 - INFO - Valid improvement (0.005567 > 0.001). Model saved.
# Epoch 4/50: 100%|██████████| 961/961 [00:04<00:00, 210.27it/s]
# 2026-02-06 21:36:12,310 - INFO - [Epoch 4] Average Loss: 0.470487
# Evaluating: 100%|██████████| 321/321 [00:01<00:00, 274.75it/s]
# 2026-02-06 21:36:13,560 - INFO - [Epoch 4] Validation AUC: 0.806914, ACC: 0.764829
# 2026-02-06 21:36:13,563 - INFO - save parameters to paras_EADCD\model_random_random_fold_3.snapshot
# 2026-02-06 21:36:13,564 - INFO - Valid improvement (0.003203 > 0.001). Model saved.
# Epoch 5/50: 100%|██████████| 961/961 [00:04<00:00, 216.93it/s]
# 2026-02-06 21:36:17,998 - INFO - [Epoch 5] Average Loss: 0.464434
# Evaluating: 100%|██████████| 321/321 [00:01<00:00, 256.55it/s]
# 2026-02-06 21:36:19,327 - INFO - [Epoch 5] Validation AUC: 0.808979, ACC: 0.767709
# 2026-02-06 21:36:19,330 - INFO - save parameters to paras_EADCD\model_random_random_fold_3.snapshot
# 2026-02-06 21:36:19,330 - INFO - Valid improvement (0.002065 > 0.001). Model saved.
# Epoch 6/50: 100%|██████████| 961/961 [00:04<00:00, 216.67it/s]
# 2026-02-06 21:36:23,769 - INFO - [Epoch 6] Average Loss: 0.458690
# Evaluating: 100%|██████████| 321/321 [00:01<00:00, 286.70it/s]
# 2026-02-06 21:36:24,963 - INFO - [Epoch 6] Validation AUC: 0.809513, ACC: 0.767697
# 2026-02-06 21:36:24,964 - INFO - Early stopping triggered at epoch 6.
# 2026-02-06 21:36:24,965 - INFO - --- random_fold_3 Best epoch: 5 ---
# 2026-02-06 21:36:24,965 - INFO - Loading best model from random_fold_3 for final test evaluation...
# 2026-02-06 21:36:24,997 - INFO - load parameters from paras_EADCD\model_random_random_fold_3.snapshot
# Evaluating: 100%|██████████| 320/320 [00:01<00:00, 274.57it/s]
# 2026-02-06 21:36:26,240 - INFO - random_fold_3 Test Performance --- AUC: 0.807690, ACC: 0.765958, RMSE: 0.400054, F1: 0.835893
# 2026-02-06 21:36:26,241 - INFO -
# ==================== Starting Random Split Fold 4/5 ====================
# 2026-02-06 21:36:30,640 - INFO - random_fold_4: Train=247254, Val=82418, Test=79946
# 2026-02-06 21:36:55,147 - INFO - Training MIRT (dim=16)... (lr=0.002)
# Epoch 1/50: 100%|██████████| 966/966 [00:04<00:00, 205.81it/s]
# 2026-02-06 21:36:59,852 - INFO - [Epoch 1] Average Loss: 0.567967
# Evaluating: 100%|██████████| 322/322 [00:01<00:00, 307.63it/s]
# 2026-02-06 21:37:00,975 - INFO - [Epoch 1] Validation AUC: 0.784761, ACC: 0.742265
# 2026-02-06 21:37:00,984 - INFO - save parameters to paras_EADCD\model_random_random_fold_4.snapshot
# 2026-02-06 21:37:00,984 - INFO - Valid improvement (0.784761 > 0.001). Model saved.
# Epoch 2/50: 100%|██████████| 966/966 [00:04<00:00, 203.09it/s]
# 2026-02-06 21:37:05,742 - INFO - [Epoch 2] Average Loss: 0.495181
# Evaluating: 100%|██████████| 322/322 [00:01<00:00, 295.17it/s]
# 2026-02-06 21:37:06,912 - INFO - [Epoch 2] Validation AUC: 0.797776, ACC: 0.756376
# 2026-02-06 21:37:06,912 - INFO - save parameters to paras_EADCD\model_random_random_fold_4.snapshot
# 2026-02-06 21:37:06,912 - INFO - Valid improvement (0.013015 > 0.001). Model saved.
# Epoch 3/50: 100%|██████████| 966/966 [00:04<00:00, 211.40it/s]
# 2026-02-06 21:37:11,483 - INFO - [Epoch 3] Average Loss: 0.477957
# Evaluating: 100%|██████████| 322/322 [00:01<00:00, 302.04it/s]
# 2026-02-06 21:37:12,624 - INFO - [Epoch 3] Validation AUC: 0.804019, ACC: 0.762746
# 2026-02-06 21:37:12,627 - INFO - save parameters to paras_EADCD\model_random_random_fold_4.snapshot
# 2026-02-06 21:37:12,628 - INFO - Valid improvement (0.006243 > 0.001). Model saved.
# Epoch 4/50: 100%|██████████| 966/966 [00:04<00:00, 208.67it/s]
# 2026-02-06 21:37:17,259 - INFO - [Epoch 4] Average Loss: 0.468894
# Evaluating: 100%|██████████| 322/322 [00:01<00:00, 288.50it/s]
# 2026-02-06 21:37:18,453 - INFO - [Epoch 4] Validation AUC: 0.806096, ACC: 0.765185
# 2026-02-06 21:37:18,456 - INFO - save parameters to paras_EADCD\model_random_random_fold_4.snapshot
# 2026-02-06 21:37:18,457 - INFO - Valid improvement (0.002077 > 0.001). Model saved.
# Epoch 5/50: 100%|██████████| 966/966 [00:04<00:00, 200.57it/s]
# 2026-02-06 21:37:23,279 - INFO - [Epoch 5] Average Loss: 0.462637
# Evaluating: 100%|██████████| 322/322 [00:01<00:00, 320.86it/s]
# 2026-02-06 21:37:24,357 - INFO - [Epoch 5] Validation AUC: 0.807841, ACC: 0.765925
# 2026-02-06 21:37:24,360 - INFO - save parameters to paras_EADCD\model_random_random_fold_4.snapshot
# 2026-02-06 21:37:24,360 - INFO - Valid improvement (0.001744 > 0.001). Model saved.
# Epoch 6/50: 100%|██████████| 966/966 [00:04<00:00, 204.65it/s]
# 2026-02-06 21:37:29,085 - INFO - [Epoch 6] Average Loss: 0.457401
# Evaluating: 100%|██████████| 322/322 [00:01<00:00, 280.74it/s]
# 2026-02-06 21:37:30,309 - INFO - [Epoch 6] Validation AUC: 0.808745, ACC: 0.766944
# 2026-02-06 21:37:30,309 - INFO - Early stopping triggered at epoch 6.
# 2026-02-06 21:37:30,309 - INFO - --- random_fold_4 Best epoch: 5 ---
# 2026-02-06 21:37:30,309 - INFO - Loading best model from random_fold_4 for final test evaluation...
# 2026-02-06 21:37:30,346 - INFO - load parameters from paras_EADCD\model_random_random_fold_4.snapshot
# Evaluating: 100%|██████████| 313/313 [00:01<00:00, 257.17it/s]
# 2026-02-06 21:37:31,652 - INFO - random_fold_4 Test Performance --- AUC: 0.805553, ACC: 0.765629, RMSE: 0.400339, F1: 0.836211
# 2026-02-06 21:37:31,681 - INFO -
# ==================== Starting Random Split Fold 5/5 ====================
# 2026-02-06 21:37:35,742 - INFO - random_fold_5: Train=248586, Val=82862, Test=78170
# 2026-02-06 21:38:02,238 - INFO - Training MIRT (dim=16)... (lr=0.002)
# Epoch 1/50: 100%|██████████| 972/972 [00:05<00:00, 179.25it/s]
# 2026-02-06 21:38:07,667 - INFO - [Epoch 1] Average Loss: 0.567263
# Evaluating: 100%|██████████| 324/324 [00:01<00:00, 293.25it/s]
# 2026-02-06 21:38:08,864 - INFO - [Epoch 1] Validation AUC: 0.782227, ACC: 0.743344
# 2026-02-06 21:38:08,869 - INFO - save parameters to paras_EADCD\model_random_random_fold_5.snapshot
# 2026-02-06 21:38:08,870 - INFO - Valid improvement (0.782227 > 0.001). Model saved.
# Epoch 2/50: 100%|██████████| 972/972 [00:04<00:00, 199.67it/s]
# 2026-02-06 21:38:13,741 - INFO - [Epoch 2] Average Loss: 0.494962
# Evaluating: 100%|██████████| 324/324 [00:01<00:00, 277.53it/s]
# 2026-02-06 21:38:15,000 - INFO - [Epoch 2] Validation AUC: 0.795310, ACC: 0.757730
# 2026-02-06 21:38:15,003 - INFO - save parameters to paras_EADCD\model_random_random_fold_5.snapshot
# 2026-02-06 21:38:15,003 - INFO - Valid improvement (0.013083 > 0.001). Model saved.
# Epoch 3/50: 100%|██████████| 972/972 [00:05<00:00, 173.56it/s]
# 2026-02-06 21:38:20,607 - INFO - [Epoch 3] Average Loss: 0.477584
# Evaluating: 100%|██████████| 324/324 [00:00<00:00, 339.05it/s]
# 2026-02-06 21:38:21,658 - INFO - [Epoch 3] Validation AUC: 0.801615, ACC: 0.763909
# 2026-02-06 21:38:21,662 - INFO - save parameters to paras_EADCD\model_random_random_fold_5.snapshot
# 2026-02-06 21:38:21,663 - INFO - Valid improvement (0.006305 > 0.001). Model saved.
# Epoch 4/50: 100%|██████████| 972/972 [00:05<00:00, 189.26it/s]
# 2026-02-06 21:38:26,802 - INFO - [Epoch 4] Average Loss: 0.468608
# Evaluating: 100%|██████████| 324/324 [00:00<00:00, 354.88it/s]
# 2026-02-06 21:38:27,786 - INFO - [Epoch 4] Validation AUC: 0.804192, ACC: 0.765671
# 2026-02-06 21:38:27,789 - INFO - save parameters to paras_EADCD\model_random_random_fold_5.snapshot
# 2026-02-06 21:38:27,790 - INFO - Valid improvement (0.002577 > 0.001). Model saved.
# Epoch 5/50: 100%|██████████| 972/972 [00:05<00:00, 171.28it/s]
# 2026-02-06 21:38:33,468 - INFO - [Epoch 5] Average Loss: 0.462114
# Evaluating: 100%|██████████| 324/324 [00:01<00:00, 243.31it/s]
# 2026-02-06 21:38:34,885 - INFO - [Epoch 5] Validation AUC: 0.805382, ACC: 0.766407
# 2026-02-06 21:38:34,890 - INFO - save parameters to paras_EADCD\model_random_random_fold_5.snapshot
# 2026-02-06 21:38:34,891 - INFO - Valid improvement (0.001191 > 0.001). Model saved.
# Epoch 6/50: 100%|██████████| 972/972 [00:07<00:00, 136.58it/s]
# 2026-02-06 21:38:42,018 - INFO - [Epoch 6] Average Loss: 0.456446
# Evaluating: 100%|██████████| 324/324 [00:01<00:00, 292.42it/s]
# 2026-02-06 21:38:43,200 - INFO - [Epoch 6] Validation AUC: 0.806594, ACC: 0.767360
# 2026-02-06 21:38:43,205 - INFO - save parameters to paras_EADCD\model_random_random_fold_5.snapshot
# 2026-02-06 21:38:43,205 - INFO - Valid improvement (0.001211 > 0.001). Model saved.
# Epoch 7/50: 100%|██████████| 972/972 [00:05<00:00, 167.75it/s]
# 2026-02-06 21:38:49,004 - INFO - [Epoch 7] Average Loss: 0.449865
# Evaluating: 100%|██████████| 324/324 [00:01<00:00, 304.55it/s]
# 2026-02-06 21:38:50,146 - INFO - [Epoch 7] Validation AUC: 0.806857, ACC: 0.767952
# 2026-02-06 21:38:50,147 - INFO - Early stopping triggered at epoch 7.
# 2026-02-06 21:38:50,149 - INFO - --- random_fold_5 Best epoch: 6 ---
# 2026-02-06 21:38:50,150 - INFO - Loading best model from random_fold_5 for final test evaluation...
# 2026-02-06 21:38:50,178 - INFO - load parameters from paras_EADCD\model_random_random_fold_5.snapshot
# Evaluating: 100%|██████████| 306/306 [00:01<00:00, 288.26it/s]
# 2026-02-06 21:38:51,317 - INFO - random_fold_5 Test Performance --- AUC: 0.808537, ACC: 0.763298, RMSE: 0.402046, F1: 0.830678
# ==================== 5-Fold Cross-Validation Summary (Random Split) ====================
# Parameters: train_fraction=1.0, epochs=50, seed=123
# Average AUC:  0.807862 ± 0.001330
# Average ACC:  0.766070 ± 0.002069
# Average RMSE: 0.400277 ± 0.001197
# Average F1:   0.835269 ± 0.002550

# %% [markdown]
# ### NIPS

# %% [markdown]
# **100% train**

# %%
runner = ADCD_Runner(
    model_class=MIRT,
    input_dir='../../Data/data/N123',
    split_type='random',
    train_fraction=1.0,
    **hyperparams
)
runner.run()
# Out:
# 2026-02-06 21:38:51,885 - INFO - Using device: cuda
# 2026-02-06 21:38:51,895 - INFO - Loading metadata and p2k mapping...
# 2026-02-06 21:38:51,912 - INFO - 10000 users, 27599 problems, 388 skills.
# 2026-02-06 21:38:51,924 - INFO - Pre-building global problem Q-matrix...
# 2026-02-06 21:38:53,458 - INFO -
# ==================== Starting Random Split Fold 1/5 ====================
# 2026-02-06 21:39:06,497 - INFO - random_fold_1: Train=1000558, Val=333520, Test=337962
# 2026-02-06 21:40:54,221 - INFO - Training MIRT (dim=16)... (lr=0.002)
# Epoch 1/50: 100%|██████████| 3909/3909 [00:46<00:00, 84.62it/s]
# 2026-02-06 21:41:40,433 - INFO - [Epoch 1] Average Loss: 0.577684
# Evaluating: 100%|██████████| 1303/1303 [00:07<00:00, 179.34it/s]
# 2026-02-06 21:41:48,109 - INFO - [Epoch 1] Validation AUC: 0.757323, ACC: 0.708461
# 2026-02-06 21:41:48,120 - INFO - save parameters to paras_EADCD\model_random_random_fold_1.snapshot
# 2026-02-06 21:41:48,121 - INFO - Valid improvement (0.757323 > 0.001). Model saved.
# Epoch 2/50: 100%|██████████| 3909/3909 [00:21<00:00, 183.29it/s]
# 2026-02-06 21:42:09,451 - INFO - [Epoch 2] Average Loss: 0.541416
# Evaluating: 100%|██████████| 1303/1303 [00:04<00:00, 281.02it/s]
# 2026-02-06 21:42:14,441 - INFO - [Epoch 2] Validation AUC: 0.770210, ACC: 0.717642
# 2026-02-06 21:42:14,460 - INFO - save parameters to paras_EADCD\model_random_random_fold_1.snapshot
# 2026-02-06 21:42:14,462 - INFO - Valid improvement (0.012888 > 0.001). Model saved.
# Epoch 3/50: 100%|██████████| 3909/3909 [00:20<00:00, 192.31it/s]
# 2026-02-06 21:42:34,790 - INFO - [Epoch 3] Average Loss: 0.528862
# Evaluating: 100%|██████████| 1303/1303 [00:04<00:00, 280.15it/s]
# 2026-02-06 21:42:39,788 - INFO - [Epoch 3] Validation AUC: 0.774471, ACC: 0.721630
# 2026-02-06 21:42:39,790 - INFO - save parameters to paras_EADCD\model_random_random_fold_1.snapshot
# 2026-02-06 21:42:39,790 - INFO - Valid improvement (0.004260 > 0.001). Model saved.
# Epoch 4/50: 100%|██████████| 3909/3909 [00:20<00:00, 187.54it/s]
# 2026-02-06 21:43:00,635 - INFO - [Epoch 4] Average Loss: 0.521053
# Evaluating: 100%|██████████| 1303/1303 [00:04<00:00, 274.63it/s]
# 2026-02-06 21:43:05,723 - INFO - [Epoch 4] Validation AUC: 0.776565, ACC: 0.723255
# 2026-02-06 21:43:05,728 - INFO - save parameters to paras_EADCD\model_random_random_fold_1.snapshot
# 2026-02-06 21:43:05,729 - INFO - Valid improvement (0.002094 > 0.001). Model saved.
# Epoch 5/50: 100%|██████████| 3909/3909 [00:20<00:00, 188.20it/s]
# 2026-02-06 21:43:26,505 - INFO - [Epoch 5] Average Loss: 0.513445
# Evaluating: 100%|██████████| 1303/1303 [00:04<00:00, 279.44it/s]
# 2026-02-06 21:43:31,527 - INFO - [Epoch 5] Validation AUC: 0.778042, ACC: 0.724685
# 2026-02-06 21:43:31,534 - INFO - save parameters to paras_EADCD\model_random_random_fold_1.snapshot
# 2026-02-06 21:43:31,534 - INFO - Valid improvement (0.001478 > 0.001). Model saved.
# Epoch 6/50: 100%|██████████| 3909/3909 [00:21<00:00, 184.19it/s]
# 2026-02-06 21:43:52,763 - INFO - [Epoch 6] Average Loss: 0.502377
# Evaluating: 100%|██████████| 1303/1303 [00:04<00:00, 288.12it/s]
# 2026-02-06 21:43:57,623 - INFO - [Epoch 6] Validation AUC: 0.778838, ACC: 0.724646
# 2026-02-06 21:43:57,625 - INFO - Early stopping triggered at epoch 6.
# 2026-02-06 21:43:57,629 - INFO - --- random_fold_1 Best epoch: 5 ---
# 2026-02-06 21:43:57,629 - INFO - Loading best model from random_fold_1 for final test evaluation...
# 2026-02-06 21:43:57,640 - INFO - load parameters from paras_EADCD\model_random_random_fold_1.snapshot
# Evaluating: 100%|██████████| 1321/1321 [00:08<00:00, 153.27it/s]
# 2026-02-06 21:44:06,649 - INFO - random_fold_1 Test Performance --- AUC: 0.775498, ACC: 0.722330, RMSE: 0.427937, F1: 0.790848
# 2026-02-06 21:44:06,836 - INFO -
# ==================== Starting Random Split Fold 2/5 ====================
# 2026-02-06 21:44:31,423 - INFO - random_fold_2: Train=1001973, Val=333992, Test=336075
# 2026-02-06 21:46:15,607 - INFO - Training MIRT (dim=16)... (lr=0.002)
# Epoch 1/50: 100%|██████████| 3914/3914 [00:58<00:00, 66.93it/s]
# 2026-02-06 21:47:14,142 - INFO - [Epoch 1] Average Loss: 0.577537
# Evaluating: 100%|██████████| 1305/1305 [00:09<00:00, 141.81it/s]
# 2026-02-06 21:47:23,711 - INFO - [Epoch 1] Validation AUC: 0.755198, ACC: 0.707391
# 2026-02-06 21:47:23,737 - INFO - save parameters to paras_EADCD\model_random_random_fold_2.snapshot
# 2026-02-06 21:47:23,739 - INFO - Valid improvement (0.755198 > 0.001). Model saved.
# Epoch 2/50: 100%|██████████| 3914/3914 [00:24<00:00, 157.10it/s]
# 2026-02-06 21:47:48,660 - INFO - [Epoch 2] Average Loss: 0.541180
# Evaluating: 100%|██████████| 1305/1305 [00:06<00:00, 198.87it/s]
# 2026-02-06 21:47:55,587 - INFO - [Epoch 2] Validation AUC: 0.768246, ACC: 0.716529
# 2026-02-06 21:47:55,596 - INFO - save parameters to paras_EADCD\model_random_random_fold_2.snapshot
# 2026-02-06 21:47:55,597 - INFO - Valid improvement (0.013049 > 0.001). Model saved.
# Epoch 3/50: 100%|██████████| 3914/3914 [00:21<00:00, 181.84it/s]
# 2026-02-06 21:48:17,128 - INFO - [Epoch 3] Average Loss: 0.528579
# Evaluating: 100%|██████████| 1305/1305 [00:04<00:00, 277.28it/s]
# 2026-02-06 21:48:22,169 - INFO - [Epoch 3] Validation AUC: 0.772656, ACC: 0.720362
# 2026-02-06 21:48:22,179 - INFO - save parameters to paras_EADCD\model_random_random_fold_2.snapshot
# 2026-02-06 21:48:22,181 - INFO - Valid improvement (0.004409 > 0.001). Model saved.
# Epoch 4/50: 100%|██████████| 3914/3914 [00:20<00:00, 191.22it/s]
# 2026-02-06 21:48:42,654 - INFO - [Epoch 4] Average Loss: 0.520585
# Evaluating: 100%|██████████| 1305/1305 [00:04<00:00, 284.82it/s]
# 2026-02-06 21:48:47,566 - INFO - [Epoch 4] Validation AUC: 0.773942, ACC: 0.721739
# 2026-02-06 21:48:47,575 - INFO - save parameters to paras_EADCD\model_random_random_fold_2.snapshot
# 2026-02-06 21:48:47,576 - INFO - Valid improvement (0.001287 > 0.001). Model saved.
# Epoch 5/50: 100%|██████████| 3914/3914 [00:20<00:00, 193.18it/s]
# 2026-02-06 21:49:07,841 - INFO - [Epoch 5] Average Loss: 0.513082
# Evaluating: 100%|██████████| 1305/1305 [00:05<00:00, 243.34it/s]
# 2026-02-06 21:49:13,543 - INFO - [Epoch 5] Validation AUC: 0.775374, ACC: 0.722032
# 2026-02-06 21:49:13,549 - INFO - save parameters to paras_EADCD\model_random_random_fold_2.snapshot
# 2026-02-06 21:49:13,549 - INFO - Valid improvement (0.001432 > 0.001). Model saved.
# Epoch 6/50: 100%|██████████| 3914/3914 [00:22<00:00, 177.65it/s]
# 2026-02-06 21:49:35,585 - INFO - [Epoch 6] Average Loss: 0.501979
# Evaluating: 100%|██████████| 1305/1305 [00:04<00:00, 281.78it/s]
# 2026-02-06 21:49:40,543 - INFO - [Epoch 6] Validation AUC: 0.775865, ACC: 0.723242
# 2026-02-06 21:49:40,545 - INFO - Early stopping triggered at epoch 6.
# 2026-02-06 21:49:40,548 - INFO - --- random_fold_2 Best epoch: 5 ---
# 2026-02-06 21:49:40,549 - INFO - Loading best model from random_fold_2 for final test evaluation...
# 2026-02-06 21:49:40,554 - INFO - load parameters from paras_EADCD\model_random_random_fold_2.snapshot
# Evaluating: 100%|██████████| 1313/1313 [00:09<00:00, 141.17it/s]
# 2026-02-06 21:49:50,204 - INFO - random_fold_2 Test Performance --- AUC: 0.777080, ACC: 0.723580, RMSE: 0.427238, F1: 0.792002
# 2026-02-06 21:49:50,450 - INFO -
# ==================== Starting Random Split Fold 3/5 ====================
# 2026-02-06 21:50:14,724 - INFO - random_fold_3: Train=1003281, Val=334427, Test=334332
# 2026-02-06 21:51:54,186 - INFO - Training MIRT (dim=16)... (lr=0.002)
# Epoch 1/50: 100%|██████████| 3920/3920 [00:30<00:00, 128.44it/s]
# 2026-02-06 21:52:24,722 - INFO - [Epoch 1] Average Loss: 0.577401
# Evaluating: 100%|██████████| 1307/1307 [00:03<00:00, 346.45it/s]
# 2026-02-06 21:52:28,819 - INFO - [Epoch 1] Validation AUC: 0.755761, ACC: 0.708017
# 2026-02-06 21:52:28,833 - INFO - save parameters to paras_EADCD\model_random_random_fold_3.snapshot
# 2026-02-06 21:52:28,833 - INFO - Valid improvement (0.755761 > 0.001). Model saved.
# Epoch 2/50: 100%|██████████| 3920/3920 [00:19<00:00, 204.45it/s]
# 2026-02-06 21:52:48,011 - INFO - [Epoch 2] Average Loss: 0.541231
# Evaluating: 100%|██████████| 1307/1307 [00:03<00:00, 370.19it/s]
# 2026-02-06 21:52:51,837 - INFO - [Epoch 2] Validation AUC: 0.768918, ACC: 0.717334
# 2026-02-06 21:52:51,855 - INFO - save parameters to paras_EADCD\model_random_random_fold_3.snapshot
# 2026-02-06 21:52:51,856 - INFO - Valid improvement (0.013157 > 0.001). Model saved.
# Epoch 3/50: 100%|██████████| 3920/3920 [00:17<00:00, 220.17it/s]
# 2026-02-06 21:53:09,668 - INFO - [Epoch 3] Average Loss: 0.528360
# Evaluating: 100%|██████████| 1307/1307 [00:03<00:00, 368.35it/s]
# 2026-02-06 21:53:13,519 - INFO - [Epoch 3] Validation AUC: 0.773044, ACC: 0.720241
# 2026-02-06 21:53:13,527 - INFO - save parameters to paras_EADCD\model_random_random_fold_3.snapshot
# 2026-02-06 21:53:13,530 - INFO - Valid improvement (0.004126 > 0.001). Model saved.
# Epoch 4/50: 100%|██████████| 3920/3920 [00:17<00:00, 227.82it/s]
# 2026-02-06 21:53:30,737 - INFO - [Epoch 4] Average Loss: 0.520680
# Evaluating: 100%|██████████| 1307/1307 [00:03<00:00, 360.31it/s]
# 2026-02-06 21:53:34,685 - INFO - [Epoch 4] Validation AUC: 0.775428, ACC: 0.722077
# 2026-02-06 21:53:34,687 - INFO - save parameters to paras_EADCD\model_random_random_fold_3.snapshot
# 2026-02-06 21:53:34,687 - INFO - Valid improvement (0.002385 > 0.001). Model saved.
# Epoch 5/50: 100%|██████████| 3920/3920 [00:17<00:00, 227.33it/s]
# 2026-02-06 21:53:51,935 - INFO - [Epoch 5] Average Loss: 0.513103
# Evaluating: 100%|██████████| 1307/1307 [00:03<00:00, 377.35it/s]
# 2026-02-06 21:53:55,692 - INFO - [Epoch 5] Validation AUC: 0.776930, ACC: 0.723886
# 2026-02-06 21:53:55,699 - INFO - save parameters to paras_EADCD\model_random_random_fold_3.snapshot
# 2026-02-06 21:53:55,700 - INFO - Valid improvement (0.001501 > 0.001). Model saved.
# Epoch 6/50: 100%|██████████| 3920/3920 [00:17<00:00, 220.07it/s]
# 2026-02-06 21:54:13,517 - INFO - [Epoch 6] Average Loss: 0.502291
# Evaluating: 100%|██████████| 1307/1307 [00:03<00:00, 377.67it/s]
# 2026-02-06 21:54:17,271 - INFO - [Epoch 6] Validation AUC: 0.776857, ACC: 0.723464
# 2026-02-06 21:54:17,271 - INFO - Early stopping triggered at epoch 6.
# 2026-02-06 21:54:17,289 - INFO - --- random_fold_3 Best epoch: 5 ---
# 2026-02-06 21:54:17,292 - INFO - Loading best model from random_fold_3 for final test evaluation...
# 2026-02-06 21:54:17,305 - INFO - load parameters from paras_EADCD\model_random_random_fold_3.snapshot
# Evaluating: 100%|██████████| 1306/1306 [00:03<00:00, 363.41it/s]
# 2026-02-06 21:54:21,196 - INFO - random_fold_3 Test Performance --- AUC: 0.776060, ACC: 0.722922, RMSE: 0.427698, F1: 0.791274
# 2026-02-06 21:54:21,402 - INFO -
# ==================== Starting Random Split Fold 4/5 ====================
# 2026-02-06 21:54:37,367 - INFO - random_fold_4: Train=1004550, Val=334850, Test=332640
# 2026-02-06 21:55:50,178 - INFO - Training MIRT (dim=16)... (lr=0.002)
# Epoch 1/50: 100%|██████████| 3925/3925 [00:17<00:00, 223.96it/s]
# 2026-02-06 21:56:07,712 - INFO - [Epoch 1] Average Loss: 0.577563
# Evaluating: 100%|██████████| 1309/1309 [00:03<00:00, 380.65it/s]
# 2026-02-06 21:56:11,452 - INFO - [Epoch 1] Validation AUC: 0.756910, ACC: 0.707956
# 2026-02-06 21:56:11,463 - INFO - save parameters to paras_EADCD\model_random_random_fold_4.snapshot
# 2026-02-06 21:56:11,468 - INFO - Valid improvement (0.756910 > 0.001). Model saved.
# Epoch 2/50: 100%|██████████| 3925/3925 [00:17<00:00, 220.91it/s]
# 2026-02-06 21:56:29,242 - INFO - [Epoch 2] Average Loss: 0.541408
# Evaluating: 100%|██████████| 1309/1309 [00:03<00:00, 380.33it/s]
# 2026-02-06 21:56:32,974 - INFO - [Epoch 2] Validation AUC: 0.769340, ACC: 0.717014
# 2026-02-06 21:56:32,979 - INFO - save parameters to paras_EADCD\model_random_random_fold_4.snapshot
# 2026-02-06 21:56:32,980 - INFO - Valid improvement (0.012431 > 0.001). Model saved.
# Epoch 3/50: 100%|██████████| 3925/3925 [00:17<00:00, 222.63it/s]
# 2026-02-06 21:56:50,612 - INFO - [Epoch 3] Average Loss: 0.528824
# Evaluating: 100%|██████████| 1309/1309 [00:03<00:00, 381.55it/s]
# 2026-02-06 21:56:54,328 - INFO - [Epoch 3] Validation AUC: 0.774398, ACC: 0.721120
# 2026-02-06 21:56:54,341 - INFO - save parameters to paras_EADCD\model_random_random_fold_4.snapshot
# 2026-02-06 21:56:54,342 - INFO - Valid improvement (0.005057 > 0.001). Model saved.
# Epoch 4/50: 100%|██████████| 3925/3925 [00:17<00:00, 225.33it/s]
# 2026-02-06 21:57:11,765 - INFO - [Epoch 4] Average Loss: 0.520978
# Evaluating: 100%|██████████| 1309/1309 [00:03<00:00, 375.01it/s]
# 2026-02-06 21:57:15,546 - INFO - [Epoch 4] Validation AUC: 0.776406, ACC: 0.722616
# 2026-02-06 21:57:15,554 - INFO - save parameters to paras_EADCD\model_random_random_fold_4.snapshot
# 2026-02-06 21:57:15,555 - INFO - Valid improvement (0.002008 > 0.001). Model saved.
# Epoch 5/50: 100%|██████████| 3925/3925 [00:17<00:00, 225.52it/s]
# 2026-02-06 21:57:32,962 - INFO - [Epoch 5] Average Loss: 0.513326
# Evaluating: 100%|██████████| 1309/1309 [00:03<00:00, 368.27it/s]
# 2026-02-06 21:57:36,811 - INFO - [Epoch 5] Validation AUC: 0.777446, ACC: 0.723703
# 2026-02-06 21:57:36,816 - INFO - save parameters to paras_EADCD\model_random_random_fold_4.snapshot
# 2026-02-06 21:57:36,817 - INFO - Valid improvement (0.001040 > 0.001). Model saved.
# Epoch 6/50: 100%|██████████| 3925/3925 [00:17<00:00, 226.71it/s]
# 2026-02-06 21:57:54,136 - INFO - [Epoch 6] Average Loss: 0.502448
# Evaluating: 100%|██████████| 1309/1309 [00:03<00:00, 377.28it/s]
# 2026-02-06 21:57:57,919 - INFO - [Epoch 6] Validation AUC: 0.778137, ACC: 0.723945
# 2026-02-06 21:57:57,919 - INFO - Early stopping triggered at epoch 6.
# 2026-02-06 21:57:57,919 - INFO - --- random_fold_4 Best epoch: 5 ---
# 2026-02-06 21:57:57,919 - INFO - Loading best model from random_fold_4 for final test evaluation...
# 2026-02-06 21:57:57,952 - INFO - load parameters from paras_EADCD\model_random_random_fold_4.snapshot
# Evaluating: 100%|██████████| 1300/1300 [00:03<00:00, 375.12it/s]
# 2026-02-06 21:58:01,685 - INFO - random_fold_4 Test Performance --- AUC: 0.775112, ACC: 0.721798, RMSE: 0.428114, F1: 0.790324
# 2026-02-06 21:58:01,903 - INFO -
# ==================== Starting Random Split Fold 5/5 ====================
# 2026-02-06 21:58:15,647 - INFO - random_fold_5: Train=1005756, Val=335253, Test=331031
# 2026-02-06 21:59:28,045 - INFO - Training MIRT (dim=16)... (lr=0.002)
# Epoch 1/50: 100%|██████████| 3929/3929 [00:17<00:00, 224.27it/s]
# 2026-02-06 21:59:45,580 - INFO - [Epoch 1] Average Loss: 0.577338
# Evaluating: 100%|██████████| 1310/1310 [00:03<00:00, 375.65it/s]
# 2026-02-06 21:59:49,360 - INFO - [Epoch 1] Validation AUC: 0.755688, ACC: 0.707567
# 2026-02-06 21:59:49,369 - INFO - save parameters to paras_EADCD\model_random_random_fold_5.snapshot
# 2026-02-06 21:59:49,371 - INFO - Valid improvement (0.755688 > 0.001). Model saved.
# Epoch 2/50: 100%|██████████| 3929/3929 [00:17<00:00, 220.97it/s]
# 2026-02-06 22:00:07,157 - INFO - [Epoch 2] Average Loss: 0.541054
# Evaluating: 100%|██████████| 1310/1310 [00:03<00:00, 378.76it/s]
# 2026-02-06 22:00:10,917 - INFO - [Epoch 2] Validation AUC: 0.768902, ACC: 0.716289
# 2026-02-06 22:00:10,918 - INFO - save parameters to paras_EADCD\model_random_random_fold_5.snapshot
# 2026-02-06 22:00:10,918 - INFO - Valid improvement (0.013214 > 0.001). Model saved.
# Epoch 3/50: 100%|██████████| 3929/3929 [00:17<00:00, 225.24it/s]
# 2026-02-06 22:00:28,365 - INFO - [Epoch 3] Average Loss: 0.528455
# Evaluating: 100%|██████████| 1310/1310 [00:03<00:00, 378.04it/s]
# 2026-02-06 22:00:32,120 - INFO - [Epoch 3] Validation AUC: 0.772020, ACC: 0.719889
# 2026-02-06 22:00:32,126 - INFO - save parameters to paras_EADCD\model_random_random_fold_5.snapshot
# 2026-02-06 22:00:32,128 - INFO - Valid improvement (0.003118 > 0.001). Model saved.
# Epoch 4/50: 100%|██████████| 3929/3929 [00:17<00:00, 221.36it/s]
# 2026-02-06 22:00:49,881 - INFO - [Epoch 4] Average Loss: 0.520646
# Evaluating: 100%|██████████| 1310/1310 [00:03<00:00, 373.74it/s]
# 2026-02-06 22:00:53,669 - INFO - [Epoch 4] Validation AUC: 0.774606, ACC: 0.721184
# 2026-02-06 22:00:53,683 - INFO - save parameters to paras_EADCD\model_random_random_fold_5.snapshot
# 2026-02-06 22:00:53,685 - INFO - Valid improvement (0.002586 > 0.001). Model saved.
# Epoch 5/50: 100%|██████████| 3929/3929 [00:17<00:00, 221.53it/s]
# 2026-02-06 22:01:11,426 - INFO - [Epoch 5] Average Loss: 0.513206
# Evaluating: 100%|██████████| 1310/1310 [00:03<00:00, 363.06it/s]
# 2026-02-06 22:01:15,328 - INFO - [Epoch 5] Validation AUC: 0.775777, ACC: 0.721768
# 2026-02-06 22:01:15,335 - INFO - save parameters to paras_EADCD\model_random_random_fold_5.snapshot
# 2026-02-06 22:01:15,336 - INFO - Valid improvement (0.001172 > 0.001). Model saved.
# Epoch 6/50: 100%|██████████| 3929/3929 [00:17<00:00, 228.64it/s]
# 2026-02-06 22:01:32,528 - INFO - [Epoch 6] Average Loss: 0.502106
# Evaluating: 100%|██████████| 1310/1310 [00:03<00:00, 370.42it/s]
# 2026-02-06 22:01:36,361 - INFO - [Epoch 6] Validation AUC: 0.776132, ACC: 0.722177
# 2026-02-06 22:01:36,363 - INFO - Early stopping triggered at epoch 6.
# 2026-02-06 22:01:36,364 - INFO - --- random_fold_5 Best epoch: 5 ---
# 2026-02-06 22:01:36,365 - INFO - Loading best model from random_fold_5 for final test evaluation...
# 2026-02-06 22:01:36,368 - INFO - load parameters from paras_EADCD\model_random_random_fold_5.snapshot
# Evaluating: 100%|██████████| 1294/1294 [00:03<00:00, 361.17it/s]
# 2026-02-06 22:01:40,248 - INFO - random_fold_5 Test Performance --- AUC: 0.775910, ACC: 0.723014, RMSE: 0.427621, F1: 0.790724
# ==================== 5-Fold Cross-Validation Summary (Random Split) ====================
# Parameters: train_fraction=1.0, epochs=50, seed=123
# Average AUC:  0.775932 ± 0.000663
# Average ACC:  0.722729 ± 0.000611
# Average RMSE: 0.427722 ± 0.000298
# Average F1:   0.791035 ± 0.000571
